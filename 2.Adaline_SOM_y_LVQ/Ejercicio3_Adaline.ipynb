# %%
# Este codigo solo muestra los puntos clasifiacados segun su clase
import numpy as np
import matplotlib.pyplot as plt

# atributos     ->   [x1, x2]
individuo = np.array([[-1, -1], 
                      [-1,  1],  
                      [1,  -1], 
                      [1,   1],
                     ])
# 1 : true    -1 : false
clases = np.array([1, 1, -1, -1])

# Gráfica de dispersión (x1, x2)
plt.figure(figsize=(7, 7))
plt.title("Data SET", fontsize=20)
plt.scatter(individuo [clases == -1].T[0], 
            individuo [clases == -1].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="false")
plt.scatter(individuo [clases == 1].T[0],
            individuo [clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.grid()
plt.show()

# %%
# Este codigo ejecuta las epocas definidas en el while.

# pesos    se pueden cambiar
w1 = 0.2
w2 = 0.2
# bias   se puede cambiar
b = 0.2
# α parámetro de aprendizaje  se puede cambiar
pa = 0.05
numEpocas=25 # **aqui se cambia el numero de epocas**
# épocas 
epocas = 0
# guarda la suma de los errores por iteracion y vuelve a 0 al incio de cada epoca
sumaErrores=0
# se guarda el error por epoca
error= []
# contaSinError = 0
longitud = len(clases)
# guarda los aciertos de cada epoca
# aciertos = []
while epocas != numEpocas:   
    print("\n--- Epoca:", epocas+1, "---")
    for i in range(individuo.shape[0]):
        print("Iteracion:", i + 1)  # Imprimir el índice de la fila
        print("num1:", individuo[i, 0], "num2:", individuo[i, 1])
        y = (w1 * individuo[i, 0]) + (w2 * individuo[i, 1]) + b
        print("Y:", y)

        # Verificar si la predicción es correcta
        if y == clases[i]:
            print("No actualizo pesos, ni bias")
            #contaSinError += 1
        else:
            print("Actualizo pesos y bias")
            w1 = w1 + pa * (clases[i]-y) * individuo[i, 0]
            w2 = w2 + pa * (clases[i]-y) * individuo[i, 1]
            b = b + pa * (clases[i]-y)
            print("w1_new:", w1, "w2_new::", w2, "b_new:", b)
            # calculo el error en la iteracion correpondiente
            sumaErrores=(((clases[i]-y) ** 2) /2)+sumaErrores
    # Incrementar épocas después de recorrer todos los individuos
    epocas += 1
    print("Epocas:", epocas, "SumaErrores:", sumaErrores)
    error.append(sumaErrores)
    sumaErrores = 0
# Out:
# --- Epoca: 1 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: -0.2
# Actualizo pesos y bias
# w1_new: 0.14 w2_new:: 0.14 b_new: 0.26
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.26
# Actualizo pesos y bias
# w1_new: 0.10300000000000001 w2_new:: 0.17700000000000002 b_new: 0.297
# Iteracion: 3
# num1: 1 num2: -1
# Y: 0.22299999999999998
# Actualizo pesos y bias
# w1_new: 0.04185000000000001 w2_new:: 0.23815000000000003 b_new: 0.23585
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.51585
# Actualizo pesos y bias
# w1_new: -0.03394249999999999 w2_new:: 0.16235750000000004 b_new: 0.16005750000000002
# Epocas: 1 SumaErrores: 2.89056511125
#
# --- Epoca: 2 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.03164249999999996
# Actualizo pesos y bias
# w1_new: -0.08236037499999999 w2_new:: 0.11393962500000004 b_new: 0.20847537500000002
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.40477537500000005
# Actualizo pesos y bias
# w1_new: -0.11212160624999998 w2_new:: 0.14370085625000004 b_new: 0.23823660625
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.017585856250000004
# Actualizo pesos y bias
# w1_new: -0.16124231343749998 w2_new:: 0.19282156343750004 b_new: 0.1891158990625
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.22069514906250007
# Actualizo pesos y bias
# w1_new: -0.22227707089062498 w2_new:: 0.13178680598437503 b_new: 0.128081141609375
# Epocas: 2 SumaErrores: 1.8736213993987025
#
# --- Epoca: 3 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.21857140651562496
# Actualizo pesos y bias
# w1_new: -0.2613485005648437 w2_new:: 0.09271537631015628 b_new: 0.16715257128359376
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.5212164481585937
# Actualizo pesos y bias
# w1_new: -0.285287678156914 w2_new:: 0.1166545539022266 b_new: 0.19109174887566407
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.21085048318347652
# Actualizo pesos y bias
# w1_new: -0.3247451539977402 w2_new:: 0.15611202974305277 b_new: 0.1516342730348379
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.01699885121984951
# Actualizo pesos y bias
# w1_new: -0.3738952114367477 w2_new:: 0.10696197230404525 b_new: 0.10248421559583037
# Epocas: 3 SumaErrores: 1.2144562773118446
#
# --- Epoca: 4 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.3694174547285328
# Actualizo pesos y bias
# w1_new: -0.4054243387003211 w2_new:: 0.07543284504047189 b_new: 0.13401334285940375
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.6148705266001967
# Actualizo pesos y bias
# w1_new: -0.42468081237031124 w2_new:: 0.09468931871046206 b_new: 0.15326981652939392
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.3661003145513794
# Actualizo pesos y bias
# w1_new: -0.45637579664274225 w2_new:: 0.12638430298289308 b_new: 0.12157483225696289
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.20841666140288626
# Actualizo pesos y bias
# w1_new: -0.49595496357259794 w2_new:: 0.08680513605303739 b_new: 0.0819956653271072
# Epocas: 4 SumaErrores: 0.7871960254193322
#
# --- Epoca: 5 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.49114549284666775
# Actualizo pesos y bias
# w1_new: -0.5213976889302645 w2_new:: 0.06136241069537077 b_new: 0.10743839068477382
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.690198490310409
# Actualizo pesos y bias
# w1_new: -0.5368877644147441 w2_new:: 0.07685248617985031 b_new: 0.12292846616925336
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.490811784425341
# Actualizo pesos y bias
# w1_new: -0.562347175193477 w2_new:: 0.10231189695858327 b_new: 0.0974690553905204
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.3625662228443733
# Actualizo pesos y bias
# w1_new: -0.5942188640512583 w2_new:: 0.07044020810080193 b_new: 0.06559736653273907
# Epocas: 5 SumaErrores: 0.5102521719976024
#
# --- Epoca: 6 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.5893760224831955
# Actualizo pesos y bias
# w1_new: -0.6147500629270986 w2_new:: 0.049909009224961706 b_new: 0.08612856540857929
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.7507876375606395
# Actualizo pesos y bias
# w1_new: -0.6272106810490665 w2_new:: 0.06236962734692973 b_new: 0.09858918353054731
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.5909911248654489
# Actualizo pesos y bias
# w1_new: -0.6476611248057941 w2_new:: 0.08282007110365729 b_new: 0.07813873977381976
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.48670231392831703
# Actualizo pesos y bias
# w1_new: -0.6733260091093782 w2_new:: 0.05715518680007314 b_new: 0.052473855470235614
# Epocas: 6 SumaErrores: 0.3307408134848515
#
# --- Epoca: 7 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.6686446777795407
# Actualizo pesos y bias
# w1_new: -0.6898937752204012 w2_new:: 0.04058742068905018 b_new: 0.06904162158125858
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.79952281749071
# Actualizo pesos y bias
# w1_new: -0.6999176343458657 w2_new:: 0.05061127981451468 b_new: 0.07906548070672309
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.6714634334536573
# Actualizo pesos y bias
# w1_new: -0.7163444626731829 w2_new:: 0.06703810814183181 b_new: 0.06263865237940595
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.5866677021519452
# Actualizo pesos y bias
# w1_new: -0.7370110775655856 w2_new:: 0.04637149324942907 b_new: 0.04197203748700321
# Epocas: 7 SumaErrores: 0.21438365713655005
#
# --- Epoca: 8 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.7326116218031598
# Actualizo pesos y bias
# w1_new: -0.7503804964754276 w2_new:: 0.03300207433958705 b_new: 0.05534145639684523
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.8387240272118598
# Actualizo pesos y bias
# w1_new: -0.7584442951148346 w2_new:: 0.04106587297899406 b_new: 0.06340525503625224
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.7361049130575764
# Actualizo pesos y bias
# w1_new: -0.7716390494619557 w2_new:: 0.054260627326115245 b_new: 0.05021050068913106
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.6671679214467094
# Actualizo pesos y bias
# w1_new: -0.7882806533896203 w2_new:: 0.03761902339845072 b_new: 0.03356889676146653
# Epocas: 8 SumaErrores: 0.13896214680997523
#
# --- Epoca: 9 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.7842305267526362
# Actualizo pesos y bias
# w1_new: -0.7990691270519885 w2_new:: 0.026830549736082523 b_new: 0.044357370423834724
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.8702570472119058
# Actualizo pesos y bias
# w1_new: -0.8055562746913932 w2_new:: 0.03331769737548723 b_new: 0.05084451806323943
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.7880294540036411
# Actualizo pesos y bias
# w1_new: -0.8161548019912112 w2_new:: 0.04391622467530518 b_new: 0.04024599076342149
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.7319925865524844
# Actualizo pesos y bias
# w1_new: -0.8295551726635869 w2_new:: 0.0305158540029294 b_new: 0.02684562009104571
# Epocas: 9 SumaErrores: 0.09007459270822027
#
# --- Epoca: 10 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.8258849387517032
# Actualizo pesos y bias
# w1_new: -0.8382609257260017 w2_new:: 0.02181010094051456 b_new: 0.03555137315346055
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.8956223998199769
# Actualizo pesos y bias
# w1_new: -0.8434798057350029 w2_new:: 0.027028980949515714 b_new: 0.0407702531624617
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.8297385335220568
# Actualizo pesos y bias
# w1_new: -0.8519928790589001 w2_new:: 0.03554205427341287 b_new: 0.03225717983856455
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.7841936449469227
# Actualizo pesos y bias
# w1_new: -0.8627831968115539 w2_new:: 0.024751736520759005 b_new: 0.02146686208591068
# Epocas: 10 SumaErrores: 0.058386043910676755
#
# --- Epoca: 11 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.8594983223767055
# Actualizo pesos y bias
# w1_new: -0.8698082806927186 w2_new:: 0.017726652639594283 b_new: 0.028491945967075404
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9160268792993883
# Actualizo pesos y bias
# w1_new: -0.8740069367277492 w2_new:: 0.021925308674624867 b_new: 0.03269060200210599
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.8632416434002681
# Actualizo pesos y bias
# w1_new: -0.8808448545577358 w2_new:: 0.028763226504611463 b_new: 0.025852684172119392
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.8262289438810049
# Actualizo pesos y bias
# w1_new: -0.8895334073636855 w2_new:: 0.020074673698661706 b_new: 0.017164131366169635
# Epocas: 11 SumaErrores: 0.037845717229865024
#
# --- Epoca: 12 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.8866228650311935
# Actualizo pesos y bias
# w1_new: -0.8952022641121258 w2_new:: 0.014405816950221379 b_new: 0.022832988114609962
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9324410691769571
# Actualizo pesos y bias
# w1_new: -0.8985802106532779 w2_new:: 0.017783763491373523 b_new: 0.026210934655762106
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.8901530394888894
# Actualizo pesos y bias
# w1_new: -0.9040725586788334 w2_new:: 0.023276111516929057 b_new: 0.02071858663020657
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.8600778605316978
# Actualizo pesos y bias
# w1_new: -0.9110686656522485 w2_new:: 0.016280004543513946 b_new: 0.01372247965679146
# Epocas: 12 SumaErrores: 0.024531571857302092
#
# --- Epoca: 13 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.908511140765526
# Actualizo pesos y bias
# w1_new: -0.9156431086139722 w2_new:: 0.011705561581790244 b_new: 0.018296922618515163
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9456455928142776
# Actualizo pesos y bias
# w1_new: -0.9183608289732583 w2_new:: 0.014423281941076362 b_new: 0.02101464297780128
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9117694679365334
# Actualizo pesos y bias
# w1_new: -0.9227723555764317 w2_new:: 0.018834808544249695 b_new: 0.016603116374627948
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.887334430657554
# Actualizo pesos y bias
# w1_new: -0.9284056340435539 w2_new:: 0.013201530077127396 b_new: 0.010969837907505648
# Epocas: 13 SumaErrores: 0.015901385123998316
#
# --- Epoca: 14 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9261739418739321
# Actualizo pesos y bias
# w1_new: -0.9320969369498573 w2_new:: 0.009510227170824 b_new: 0.014661140813809044
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9562683049344903
# Actualizo pesos y bias
# w1_new: -0.9342835217031328 w2_new:: 0.011696811924099484 b_new: 0.016847725567084526
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9291326080601476
# Actualizo pesos y bias
# w1_new: -0.9378268913001254 w2_new:: 0.015240181521092102 b_new: 0.013304355970091908
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9092823538089414
# Actualizo pesos y bias
# w1_new: -0.9423627736096784 w2_new:: 0.010704299211539172 b_new: 0.008768473660538978
# Epocas: 14 SumaErrores: 0.01030731329126951
#
# --- Epoca: 15 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9404269480586782
# Actualizo pesos y bias
# w1_new: -0.9453414262067444 w2_new:: 0.007725646614473083 b_new: 0.011747126257605068
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9648141990788226
# Actualizo pesos y bias
# w1_new: -0.9471007162528033 w2_new:: 0.009484936660531953 b_new: 0.013506416303663938
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9430792366096714
# Actualizo pesos y bias
# w1_new: -0.9499467544223198 w2_new:: 0.012330974830048382 b_new: 0.010660378134147509
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9269554014581238
# Actualizo pesos y bias
# w1_new: -0.9535989843494136 w2_new:: 0.008678744902954574 b_new: 0.0070081482070537
# Epocas: 15 SumaErrores: 0.00668123789257489
#
# --- Epoca: 16 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9519283876535127
# Actualizo pesos y bias
# w1_new: -0.956002564966738 w2_new:: 0.00627516428563021 b_new: 0.009411728824378063
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9716894580767462
# Actualizo pesos y bias
# w1_new: -0.9574180920629006 w2_new:: 0.007690691381792899 b_new: 0.010827255920540752
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9542815275241527
# Actualizo pesos y bias
# w1_new: -0.959704015686693 w2_new:: 0.009976615005585263 b_new: 0.008541332296748388
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9411860683843594
# Actualizo pesos y bias
# w1_new: -0.962644712267475 w2_new:: 0.007035918424803231 b_new: 0.005600635715966357
# Epocas: 16 SumaErrores: 0.004330811987596657
#
# --- Epoca: 17 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9612094295586381
# Actualizo pesos y bias
# w1_new: -0.9645842407895431 w2_new:: 0.0050963899027351356 b_new: 0.007540164238034453
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9772207949303127
# Actualizo pesos y bias
# w1_new: -0.9657232010430274 w2_new:: 0.006235350156219502 b_new: 0.008679124491518819
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.963279426707728
# Actualizo pesos y bias
# w1_new: -0.9675592297076411 w2_new:: 0.0080713788208331 b_new: 0.00684309582690522
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9526447550599028
# Actualizo pesos y bias
# w1_new: -0.9699269919546459 w2_new:: 0.005703616573828238 b_new: 0.004475333579900358
# Epocas: 17 SumaErrores: 0.002807260132511426
#
# --- Epoca: 18 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9686987089607181
# Actualizo pesos y bias
# w1_new: -0.9714920565066101 w2_new:: 0.004138552021864143 b_new: 0.006040398131864454
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9816710066603387
# Actualizo pesos y bias
# w1_new: -0.9724085061735932 w2_new:: 0.005055001688847208 b_new: 0.00695684779884752
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9705066600635929
# Actualizo pesos y bias
# w1_new: -0.9738831731704135 w2_new:: 0.006529668685667565 b_new: 0.005482180802027163
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9618713236827189
# Actualizo pesos y bias
# w1_new: -0.9757896069862776 w2_new:: 0.004623234869803509 b_new: 0.003575746986163107
# Epocas: 18 SumaErrores: 0.0018196879379418205
#
# --- Epoca: 19 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9747421191026372
# Actualizo pesos y bias
# w1_new: -0.9770525010311457 w2_new:: 0.003360340824935369 b_new: 0.004838641031031247
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9852514828871124
# Actualizo pesos y bias
# w1_new: -0.9777899268867901 w2_new:: 0.00409776668057975 b_new: 0.005576066886675628
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9763116266806942
# Actualizo pesos y bias
# w1_new: -0.9789743455527554 w2_new:: 0.005282185346545042 b_new: 0.004391648220710336
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9693005119855
# Actualizo pesos y bias
# w1_new: -0.9805093199534805 w2_new:: 0.0037472109458200438 b_new: 0.002856673819985338
# Epocas: 19 SumaErrores: 0.0011795384496608653
#
# --- Epoca: 20 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9796187828276457
# Actualizo pesos y bias
# w1_new: -0.9815283808120981 w2_new:: 0.002728150087202328 b_new: 0.0038757346786030536
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9881322655779035
# Actualizo pesos y bias
# w1_new: -0.982121767533203 w2_new:: 0.0033215368083071555 b_new: 0.004469121399707881
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9809741829418023
# Actualizo pesos y bias
# w1_new: -0.9830730583861129 w2_new:: 0.004272827661217042 b_new: 0.0035178305467979945
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9752824001780979
# Actualizo pesos y bias
# w1_new: -0.984308938377208 w2_new:: 0.0030369476701219353 b_new: 0.002281950555702888
# Epocas: 20 SumaErrores: 0.0007645892947138945
#
# --- Epoca: 21 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9835539412627889
# Actualizo pesos y bias
# w1_new: -0.9851312413140686 w2_new:: 0.0022146447332613826 b_new: 0.0031042534925634405
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9904501395398935
# Actualizo pesos y bias
# w1_new: -0.985608734337074 w2_new:: 0.0026921377562667092 b_new: 0.003581746515568767
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.984719125577772
# Actualizo pesos y bias
# w1_new: -0.9863727780581854 w2_new:: 0.003456181477378111 b_new: 0.0028177027944573654
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9800988937863498
# Actualizo pesos y bias
# w1_new: -0.9873678333688679 w2_new:: 0.002461126166695603 b_new: 0.0018226474837748576
# Epocas: 21 SumaErrores: 0.0004956159172150949
#
# --- Epoca: 22 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9867293546859471
# Actualizo pesos y bias
# w1_new: -0.9880313656345705 w2_new:: 0.00179759390099296 b_new: 0.0024861797494775007
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.992315139285041
# Actualizo pesos y bias
# w1_new: -0.9884156086703184 w2_new:: 0.00218183693674091 b_new: 0.0028704227852254507
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9877270228218339
# Actualizo pesos y bias
# w1_new: -0.9890292575292268 w2_new:: 0.0027954857956492157 b_new: 0.002256773926317145
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9839769978072603
# Actualizo pesos y bias
# w1_new: -0.9898304076388638 w2_new:: 0.001994335686012232 b_new: 0.0014556238166801617
# Epocas: 22 SumaErrores: 0.0003212648396720199
#
# --- Epoca: 23 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9892916957695317
# Actualizo pesos y bias
# w1_new: -0.9903658228503872 w2_new:: 0.0014589204744888166 b_new: 0.0019910390282035775
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9938157823530795
# Actualizo pesos y bias
# w1_new: -0.9906750337327332 w2_new:: 0.0017681313568348393 b_new: 0.0023002499105496
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9901429151790185
# Actualizo pesos y bias
# w1_new: -0.9911678879737823 w2_new:: 0.0022609855978839126 b_new: 0.0018073956695005267
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9870995067063979
# Actualizo pesos y bias
# w1_new: -0.9918129126384624 w2_new:: 0.0016159609332038077 b_new: 0.0011623710048204216
# Epocas: 23 SumaErrores: 0.00020824858789152194
#
# --- Epoca: 24 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.991359322710079
# Actualizo pesos y bias
# w1_new: -0.9922449465029585 w2_new:: 0.001183927068707757 b_new: 0.0015944048693164723
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.9950232784409827
# Actualizo pesos y bias
# w1_new: -0.9924937825809094 w2_new:: 0.0014327631466586215 b_new: 0.001843240947267337
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9920833047803007
# Actualizo pesos y bias
# w1_new: -0.9928896173418943 w2_new:: 0.0018285979076435859 b_new: 0.0014474061862823726
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9896136132479684
# Actualizo pesos y bias
# w1_new: -0.9934089366794959 w2_new:: 0.0013092785700420046 b_new: 0.0009280868486807912
# Epocas: 24 SumaErrores: 0.000134990077234466
#
# --- Epoca: 25 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.9930277449581347
# Actualizo pesos y bias
# w1_new: -0.9937575494315892 w2_new:: 0.0009606658179487409 b_new: 0.0012766996007740547
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.995994914850312
# Actualizo pesos y bias
# w1_new: -0.9939578036890736 w2_new:: 0.0011609200754331413 b_new: 0.0014769538582584548
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.9936417699062483
# Actualizo pesos y bias
# w1_new: -0.9942757151937612 w2_new:: 0.0014788315801207259 b_new: 0.0011590423535708702
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9916378412600696
# Actualizo pesos y bias
# w1_new: -0.9946938231307577 w2_new:: 0.0010607236431242058 b_new: 0.00074093441657435
# Epocas: 25 SumaErrores: 8.75029180709756e-05

# %%
# Crear la gráfica de el error cuadrático medio por epoca
epocas = range(1, len(error) + 1)
plt.plot(epocas, error, marker='o', linestyle='-', color='b')  # Línea con puntos marcados
plt.title('Error cuadrático medio (LMS) por Época')  # Título de la gráfica
plt.xlabel('Época')  # Etiqueta del eje X
plt.ylabel('Error cuadrático medio')  # Etiqueta del eje Y
plt.grid(True)  # Agregar una cuadrícula para mejor visualización
plt.xticks(epocas)  # Asegurar que las épocas se muestren correctamente en el eje X
plt.show()  # Mostrar la gráfica

# %%
def validar_entrada(mensaje):
    while True:
        try:
            valor = float(input(mensaje))
            if -1 <= valor <= 1:
                return valor
            else:
                print("Error: El valor debe estar entre -1 y 1. Intente nuevamente.")
        except ValueError:
            print("Error: Ingrese un número válido.")

# Datos de ejemplo (simulando tus datos)
# atributos     ->   [x1, x2]
individuo = np.array([[-1, -1], 
                      [-1,  1],  
                      [1,  -1], 
                      [1,   1],
                     ])
# 1 : true    -1 : false
clases = np.array([1, 1, -1, -1])
# Crear la figura
plt.figure(figsize=(6, 5), dpi=200)
plt.title("Adaline con su recta de clasificacion", fontsize=15)

# Graficar los puntos de entrada
plt.scatter(individuo[clases == -1].T[0], 
            individuo[clases == -1].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="False")
plt.scatter(individuo[clases == 1].T[0],
            individuo[clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")

# Generar y graficar la región de decisión
for x1 in np.arange(-1, 1.05, 0.05):
    for x2 in np.arange(-1, 1.05, 0.05):
        # Calcular el valor de y
        y = (w1 * x1) + (w2 * x2) + b
        
        # Función de activación
        if y >= 0:
            color = "blue"  # Clase 1
        else:
            color = "red"   # Clase 0
        
        # Graficar el punto
        plt.scatter(x1, x2, marker="s", s=110,
                    color=color, alpha=0.2, linewidths=0)

# Calcular puntos para la recta (usando la ecuación w1*x1 + w2*x2 + b = 0)
x1_vals = np.array([-1.5, 1.5])  # Rango amplio para graficar
x2_vals = (-w1 * x1_vals - b) / w2  # Despejamos x2 de la ecuación

# Graficar la recta de decisión
plt.plot(x1_vals, x2_vals, color="green", linestyle="--", linewidth=2, label="Recta clasificadora")

# Solicitar valores de x1 y x2 al usuario
x1 = validar_entrada("Ingrese x1 con un valor entre -1 y 1: ")
x2 = validar_entrada("Ingrese x2 con un valor entre -1 y 1: ")

# Determinar la clase del punto ingresado
y = (w1 * x1) + (w2 * x2) + b
if y >= 0:
    color = "blue"  # Clase 1
else:
    color = "red"   # Clase -1

# Graficar el punto ingresado
plt.scatter(x1, x2, marker="*", s=200, color=color, label="Punto ingresado")

# Configuraciones adicionales del gráfico
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.show()
# Out:
# Ingrese x1 con un valor entre -1 y 1:  0
# Ingrese x2 con un valor entre -1 y 1:  0
