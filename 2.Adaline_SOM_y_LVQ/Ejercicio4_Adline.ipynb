# %%
# Este codigo solo muestra los puntos clasifiacados segun su clase
import numpy as np
import matplotlib.pyplot as plt

# atributos     ->   [x1, x2]
individuo = np.array([[-1, -1], 
                      [-1, 1],  
                      [1, -1], 
                      [1, 1],
                     ])
# 1 : true    -1 : false
clases = np.array([-1, 1, 1, -1])

# Gráfica de dispersión (x1, x2)
plt.figure(figsize=(7, 7))
plt.title("Data SET", fontsize=20)
plt.scatter(individuo [clases == -1].T[0], 
            individuo [clases == -1].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="false")
plt.scatter(individuo [clases == 1].T[0],
            individuo [clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.grid()
plt.show()

# %%
# Este codigo ejecuta las epocas definidas en el while.

# pesos    se pueden cambiar
w1 = 0.2
w2 = 0.2
# bias   se puede cambiar
b = 0.2
# α parámetro de aprendizaje  se puede cambiar
pa = 0.05
numEpocas=50 # **aqui se cambia el numero de epocas**
# épocas 
epocas = 0
# guarda la suma de los errores por iteracion y vuelve a 0 al incio de cada epoca
sumaErrores=0
# se guarda el error por epoca
error= []
# contaSinError = 0
longitud = len(clases)
# guarda los aciertos de cada epoca
# aciertos = []
while epocas != numEpocas:   
    print("\n--- Epoca:", epocas+1, "---")
    for i in range(individuo.shape[0]):
        print("Iteracion:", i + 1)  # Imprimir el índice de la fila
        print("num1:", individuo[i, 0], "num2:", individuo[i, 1])
        y = (w1 * individuo[i, 0]) + (w2 * individuo[i, 1]) + b
        print("Y:", y)

        # Verificar si la predicción es correcta
        if y == clases[i]:
            print("No actualizo pesos, ni bias")
            #contaSinError += 1
        else:
            print("Actualizo pesos y bias")
            w1 = w1 + pa * (clases[i]-y) * individuo[i, 0]
            w2 = w2 + pa * (clases[i]-y) * individuo[i, 1]
            b = b + pa * (clases[i]-y)
            print("w1_new:", w1, "w2_new::", w2, "b_new:", b)
            # calculo el error en la iteracion correpondiente
            sumaErrores=(((clases[i]-y) ** 2) /2)+sumaErrores
    # Incrementar épocas después de recorrer todos los individuos
    epocas += 1
    print("Epocas:", epocas, "SumaErrores:", sumaErrores)
    error.append(sumaErrores)
    sumaErrores = 0
# Out:
# --- Epoca: 1 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: -0.2
# Actualizo pesos y bias
# w1_new: 0.24000000000000002 w2_new:: 0.24000000000000002 b_new: 0.16
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.16
# Actualizo pesos y bias
# w1_new: 0.198 w2_new:: 0.28200000000000003 b_new: 0.202
# Iteracion: 3
# num1: 1 num2: -1
# Y: 0.118
# Actualizo pesos y bias
# w1_new: 0.2421 w2_new:: 0.23790000000000003 b_new: 0.2461
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7261000000000001
# Actualizo pesos y bias
# w1_new: 0.155795 w2_new:: 0.151595 b_new: 0.159795
# Epocas: 1 SumaErrores: 2.5514726050000007
#
# --- Epoca: 2 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: -0.147595
# Actualizo pesos y bias
# w1_new: 0.19841525 w2_new:: 0.19421525 b_new: 0.11717475
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.11297475000000001
# Actualizo pesos y bias
# w1_new: 0.1540639875 w2_new:: 0.2385665125 b_new: 0.16152601249999998
# Iteracion: 3
# num1: 1 num2: -1
# Y: 0.07702348749999999
# Actualizo pesos y bias
# w1_new: 0.200212813125 w2_new:: 0.192417686875 b_new: 0.20767483812499998
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.600305338125
# Actualizo pesos y bias
# w1_new: 0.12019754621874999 w2_new:: 0.11240241996874999 b_new: 0.12765957121875
# Epocas: 2 SumaErrores: 2.463135448010298
#
# --- Epoca: 3 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: -0.10494039496874999
# Actualizo pesos y bias
# w1_new: 0.1649505264703125 w2_new:: 0.1571554002203125 b_new: 0.08290659096718749
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.07511146471718748
# Actualizo pesos y bias
# w1_new: 0.11870609970617187 w2_new:: 0.20339982698445314 b_new: 0.12915101773132812
# Iteracion: 3
# num1: 1 num2: -1
# Y: 0.04445729045304685
# Actualizo pesos y bias
# w1_new: 0.16648323518351954 w2_new:: 0.15562269150710548 b_new: 0.17692815320867578
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.49903407989930076
# Actualizo pesos y bias
# w1_new: 0.0915315311885545 w2_new:: 0.08067098751214044 b_new: 0.10197644921371074
# Epocas: 3 SumaErrores: 2.4083577708620796
#
# --- Epoca: 4 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: -0.0702260694869842
# Actualizo pesos y bias
# w1_new: 0.1380202277142053 w2_new:: 0.12715968403779124 b_new: 0.055487752688059944
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.04462720901164588
# Actualizo pesos y bias
# w1_new: 0.0902515881647876 w2_new:: 0.17492832358720894 b_new: 0.10325639223747765
# Iteracion: 3
# num1: 1 num2: -1
# Y: 0.0185796568150563
# Actualizo pesos y bias
# w1_new: 0.1393226053240348 w2_new:: 0.12585730642796175 b_new: 0.15232740939672484
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.41750732114872136
# Actualizo pesos y bias
# w1_new: 0.06844723926659871 w2_new:: 0.05498194037052567 b_new: 0.08145204333928877
# Epocas: 4 SumaErrores: 2.3748648135749884
#
# --- Epoca: 5 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: -0.041977136297835616
# Actualizo pesos y bias
# w1_new: 0.11634838245170692 w2_new:: 0.10288308355563389 b_new: 0.033550900154180545
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.02008560125810751
# Actualizo pesos y bias
# w1_new: 0.0673526625146123 w2_new:: 0.1518788034927285 b_new: 0.08254662009127517
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.0019795208868410297
# Actualizo pesos y bias
# w1_new: 0.11745163855895435 w2_new:: 0.10177982744838646 b_new: 0.13264559613561722
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.351877062142958
# Actualizo pesos y bias
# w1_new: 0.049857785451806455 w2_new:: 0.03418597434123856 b_new: 0.06505174302846932
# Epocas: 5 SumaErrores: 2.3547872938313392
#
# --- Epoca: 6 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: -0.018992016764575695
# Actualizo pesos y bias
# w1_new: 0.09890818461357767 w2_new:: 0.08323637350300978 b_new: 0.016001343866698103
# Iteracion: 2
# num1: -1 num2: 1
# Y: 0.0003295327561302075
# Actualizo pesos y bias
# w1_new: 0.04892466125138418 w2_new:: 0.13321989686520327 b_new: 0.0659848672288916
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.0183103683849275
# Actualizo pesos y bias
# w1_new: 0.09984017967063055 w2_new:: 0.0823043784459569 b_new: 0.11690038564813798
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.29904494376472546
# Actualizo pesos y bias
# w1_new: 0.03488793248239429 w2_new:: 0.01735213125772063 b_new: 0.05194813845990172
# Epocas: 6 SumaErrores: 2.343095739266078
#
# --- Epoca: 7 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: -0.0002919252802131983
# Actualizo pesos y bias
# w1_new: 0.08487333621838364 w2_new:: 0.06733753499370998 b_new: 0.001962734723912375
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.015573066500761283
# Actualizo pesos y bias
# w1_new: 0.03409468289334558 w2_new:: 0.11811618831874804 b_new: 0.052741388048950434
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.031280117376452025
# Actualizo pesos y bias
# w1_new: 0.08565868876216819 w2_new:: 0.06655218244992543 b_new: 0.10430539391777305
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.2565162651298667
# Actualizo pesos y bias
# w1_new: 0.02283287550567485 w2_new:: 0.003726369193432097 b_new: 0.041479580661279714
# Epocas: 7 SumaErrores: 2.3365883465468
#
# --- Epoca: 8 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.014920335962172765
# Actualizo pesos y bias
# w1_new: 0.07357889230378349 w2_new:: 0.05447238599154074 b_new: -0.009266436136828926
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.02837294244907168
# Actualizo pesos y bias
# w1_new: 0.022160245181329905 w2_new:: 0.10589103311399432 b_new: 0.04215221098562466
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.04157857694703976
# Actualizo pesos y bias
# w1_new: 0.0742391740286819 w2_new:: 0.05381210426664233 b_new: 0.09423113983297665
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.22228241812830088
# Actualizo pesos y bias
# w1_new: 0.013125053122266847 w2_new:: -0.007302016639772715 b_new: 0.0331170189265616
# Epocas: 8 SumaErrores: 2.3332372193657593
#
# --- Epoca: 9 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.02729398244406747
# Actualizo pesos y bias
# w1_new: 0.06448975224447022 w2_new:: 0.04406268248243066 b_new: -0.01824768019564177
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.03867474995768133
# Actualizo pesos y bias
# w1_new: 0.012556014746586144 w2_new:: 0.09599641998031473 b_new: 0.033686057302242306
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.04975434793148628
# Actualizo pesos y bias
# w1_new: 0.06504373214316046 w2_new:: 0.04350870258374041 b_new: 0.08617377469881662
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.1947262094257175
# Actualizo pesos y bias
# w1_new: 0.00530742167187459 w2_new:: -0.01622760788754546 b_new: 0.026437464227530752
# Epocas: 9 SumaErrores: 2.331766534527624
#
# --- Epoca: 10 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.03735765044320162
# Actualizo pesos y bias
# w1_new: 0.05717530419403467 w2_new:: 0.035640274634614624 b_new: -0.02543041829462933
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.04696544785404938
# Actualizo pesos y bias
# w1_new: 0.0048270318013322044 w2_new:: 0.0879885470273171 b_new: 0.026917854098073138
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.05624366112791175
# Actualizo pesos y bias
# w1_new: 0.0576392148577278 w2_new:: 0.0351763639709215 b_new: 0.07973003715446873
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.17254561598311802
# Actualizo pesos y bias
# w1_new: -0.0009880659414281054 w2_new:: -0.023450916828234407 b_new: 0.021102756355312828
# Epocas: 10 SumaErrores: 2.3313807185836968
#
# --- Epoca: 11 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.04554173912497534
# Actualizo pesos y bias
# w1_new: 0.05128902101482066 w2_new:: 0.02882617012801436 b_new: -0.03117433060093594
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.05363718148774224
# Actualizo pesos y bias
# w1_new: -0.0013928380595664563 w2_new:: 0.08150802920240148 b_new: 0.02150752847345118
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.06139333878851676
# Actualizo pesos y bias
# w1_new: 0.05167682887985939 w2_new:: 0.028438362262975636 b_new: 0.07457719541287702
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.15469238655571205
# Actualizo pesos y bias
# w1_new: -0.006057790447926224 w2_new:: -0.029296257064809976 b_new: 0.01684257608509141
# Epocas: 11 SumaErrores: 2.3315895828301367
#
# --- Epoca: 12 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.05219662359782761
# Actualizo pesos y bias
# w1_new: 0.04655204073196515 w2_new:: 0.0233135741150814 b_new: -0.035767255094799964
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.059005721711683716
# Actualizo pesos y bias
# w1_new: -0.006398245353619041 w2_new:: 0.07626386020066558 b_new: 0.017183030990784227
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.06547907456350041
# Actualizo pesos y bias
# w1_new: 0.04687570837455598 w2_new:: 0.022989906472490565 b_new: 0.07045698471895925
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.1403225995660058
# Actualizo pesos y bias
# w1_new: -0.010140421603744315 w2_new:: -0.03402622350580973 b_new: 0.01344085474065896
# Epocas: 12 SumaErrores: 2.3320960713712093
#
# --- Epoca: 13 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.057607499850213004
# Actualizo pesos y bias
# w1_new: 0.042739953388766336 w2_new:: 0.018854151486700922 b_new: -0.03943952025185169
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.0633253221539171
# Actualizo pesos y bias
# w1_new: -0.010426312718929527 w2_new:: 0.07202041759439679 b_new: 0.013726745855844172
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.06871998445748213
# Actualizo pesos y bias
# w1_new: 0.043009686503944586 w2_new:: 0.018584418371522672 b_new: 0.06716274507871828
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.12875684995418554
# Actualizo pesos y bias
# w1_new: -0.013428155993764693 w2_new:: -0.037853424126186606 b_new: 0.010724902581009
# Epocas: 13 SumaErrores: 2.3327243979852232
#
# --- Epoca: 14 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.0620064827009603
# Actualizo pesos y bias
# w1_new: 0.039672168141283326 w2_new:: 0.015246900008861412 b_new: -0.04237542155403902
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.06680068968646094
# Actualizo pesos y bias
# w1_new: -0.01366786634303973 w2_new:: 0.06858693449318447 b_new: 0.010964612930284036
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07129018790594016
# Actualizo pesos y bias
# w1_new: 0.039896643052257284 w2_new:: 0.015022425097887454 b_new: 0.06452912232558106
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.1194481904757258
# Actualizo pesos y bias
# w1_new: -0.01607576647152901 w2_new:: -0.04094998442589884 b_new: 0.008556712801794764
# Epocas: 14 SumaErrores: 2.333374199338648
#
# --- Epoca: 15 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.0655824636992226
# Actualizo pesos y bias
# w1_new: 0.037203356713432126 w2_new:: 0.012329138759062296 b_new: -0.04472241038316637
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.0695966283375362
# Actualizo pesos y bias
# w1_new: -0.01627647470344469 w2_new:: 0.06580897017593912 b_new: 0.008757421033710446
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07332802384567336
# Actualizo pesos y bias
# w1_new: 0.03738992648883897 w2_new:: 0.012142568983655455 b_new: 0.06242382222599411
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.11195631769848854
# Actualizo pesos y bias
# w1_new: -0.01820788939608546 w2_new:: -0.04345524690126898 b_new: 0.006826006341069675
# Epocas: 15 SumaErrores: 2.3339914167681854
#
# --- Epoca: 16 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.06848914263842412
# Actualizo pesos y bias
# w1_new: 0.03521656773583575 w2_new:: 0.009969210230652233 b_new: -0.04659845079085154
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07184580829603505
# Actualizo pesos y bias
# w1_new: -0.018375722678966012 w2_new:: 0.06356150064545399 b_new: 0.0069938396239502265
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07494338370046977
# Actualizo pesos y bias
# w1_new: 0.03537144650605748 w2_new:: 0.009814331460430495 b_new: 0.06074100880897372
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.10592678677546169
# Actualizo pesos y bias
# w1_new: -0.019924892832715604 w2_new:: -0.04548200787834259 b_new: 0.005444669470200635
# Epocas: 16 SumaErrores: 2.334549910283444
#
# --- Epoca: 17 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07085157018125884
# Actualizo pesos y bias
# w1_new: 0.03361768567634734 w2_new:: 0.008060570630720354 b_new: -0.04809790903886231
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07365502408448929
# Actualizo pesos y bias
# w1_new: -0.02006506552787713 w2_new:: 0.061743321834944825 b_new: 0.005584842165362161
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07622354519745979
# Actualizo pesos y bias
# w1_new: 0.03374611173199586 w2_new:: 0.007932144575071833 b_new: 0.059396019425235154
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.10107427573230285
# Actualizo pesos y bias
# w1_new: -0.021307602054619283 w2_new:: -0.04712156921154331 b_new: 0.004342305638620009
# Epocas: 17 SumaErrores: 2.335039938009168
#
# --- Epoca: 18 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07277147690478261
# Actualizo pesos y bias
# w1_new: 0.032330971790619854 w2_new:: 0.006517004633695825 b_new: -0.04929626820661913
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07511023536354317
# Actualizo pesos y bias
# w1_new: -0.021424539977557305 w2_new:: 0.060272516401872984 b_new: 0.004459243561558031
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07723781281787226
# Actualizo pesos y bias
# w1_new: 0.03243735066333631 w2_new:: 0.006410625760979366 b_new: 0.05832113420245165
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.09716911062676734
# Actualizo pesos y bias
# w1_new: -0.022421104868002056 w2_new:: -0.048447829770359004 b_new: 0.00346267867111328
# Epocas: 18 SumaErrores: 2.3354610112610437
#
# --- Epoca: 19 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07433161330947433
# Actualizo pesos y bias
# w1_new: 0.03129547579747166 w2_new:: 0.005268750895114714 b_new: -0.05025390199436044
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07628062689671739
# Actualizo pesos y bias
# w1_new: -0.022518555547364205 w2_new:: 0.05908278223995058 b_new: 0.0035601293504754286
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07804120843683937
# Actualizo pesos y bias
# w1_new: 0.03138350487447777 w2_new:: 0.005180721818108608 b_new: 0.0574621897723174
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.09402641646490378
# Actualizo pesos y bias
# w1_new: -0.023317815948767424 w2_new:: -0.049520599005136584 b_new: 0.0027608689490722094
# Epocas: 19 SumaErrores: 2.3358175251001643
#
# --- Epoca: 20 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07559928390297621
# Actualizo pesos y bias
# w1_new: 0.03046214824638139 w2_new:: 0.004259365190012229 b_new: -0.051019095246076604
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07722187830244576
# Actualizo pesos y bias
# w1_new: -0.023398945668740893 w2_new:: 0.05812045910513451 b_new: 0.0028419986690456783
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07867740610482972
# Actualizo pesos y bias
# w1_new: 0.030534924636500593 w2_new:: 0.004186588799893025 b_new: 0.056775868974287165
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.09149738241068078
# Actualizo pesos y bias
# w1_new: -0.024039944484033453 w2_new:: -0.05038828032064102 b_new: 0.002200999853753119
# Epocas: 20 SumaErrores: 2.336116138438228
#
# --- Epoca: 21 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.0766292246584276
# Actualizo pesos y bias
# w1_new: 0.029791516748887935 w2_new:: 0.0034431809122803664 b_new: -0.05163046137916827
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07797879721577583
# Actualizo pesos y bias
# w1_new: -0.024107423111900866 w2_new:: 0.05734212077306917 b_new: 0.0022684784816205325
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07918106540334949
# Actualizo pesos y bias
# w1_new: 0.029851630158266612 w2_new:: 0.003383067502901689 b_new: 0.05622753175178801
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08946222941295631
# Actualizo pesos y bias
# w1_new: -0.024621481312381205 w2_new:: -0.05109004396774613 b_new: 0.001754420281140194
# Epocas: 21 SumaErrores: 2.336364247938968
#
# --- Epoca: 22 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07746594556126754
# Actualizo pesos y bias
# w1_new: 0.02925181596568218 w2_new:: 0.0027832533103172574 b_new: -0.05211887699692319
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07858743965228812
# Actualizo pesos y bias
# w1_new: -0.02467755601693223 w2_new:: 0.05671262529293167 b_new: 0.001810494985691219
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07957968632417267
# Actualizo pesos y bias
# w1_new: 0.029301428299276407 w2_new:: 0.0027336409767230313 b_new: 0.055789479301899855
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08782454857789929
# Actualizo pesos y bias
# w1_new: -0.025089799129618555 w2_new:: -0.05165758645217193 b_new: 0.0013982518730048937
# Epocas: 22 SumaErrores: 2.336569138216212
#
# --- Epoca: 23 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07814563745479537
# Actualizo pesos y bias
# w1_new: 0.028817482743121216 w2_new:: 0.0022496954205678404 b_new: -0.05250902999973488
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07907681732228825
# Actualizo pesos y bias
# w1_new: -0.025136358122993196 w2_new:: 0.05620353628668225 b_new: 0.0014448108663795353
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.07989508354329591
# Actualizo pesos y bias
# w1_new: 0.0288583960541716 w2_new:: 0.002208782109517457 b_new: 0.05543956504354433
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.0865067432072334
# Actualizo pesos y bias
# w1_new: -0.025466941106190077 w2_new:: -0.05211655505084422 b_new: 0.0011142278831826544
# Epocas: 23 SumaErrores: 2.3367375438704885
#
# --- Epoca: 24 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07869772404021697
# Actualizo pesos y bias
# w1_new: 0.02846794509582077 w2_new:: 0.0018183311511666272 b_new: -0.05282065831882819
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07947027226348233
# Actualizo pesos y bias
# w1_new: -0.025505568517353354 w2_new:: 0.05579184476434075 b_new: 0.0011528552943459308
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08014455798734817
# Actualizo pesos y bias
# w1_new: 0.02850165938201405 w2_new:: 0.0017846168649733457 b_new: 0.055160083193713336
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08544635944070073
# Actualizo pesos y bias
# w1_new: -0.025770658590020985 w2_new:: -0.05248770110706169 b_new: 0.0008877652216782994
# Epocas: 24 SumaErrores: 2.3368754569614474
#
# --- Epoca: 25 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07914612491876097
# Actualizo pesos y bias
# w1_new: 0.028186647655917073 w2_new:: 0.0014696051388763676 b_new: -0.05306954102425976
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.07978658354130047
# Actualizo pesos y bias
# w1_new: -0.02580268152114796 w2_new:: 0.0554589343159414 b_new: 0.0009197881528052732
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08034182768428408
# Actualizo pesos y bias
# w1_new: 0.028214409863066246 w2_new:: 0.0014418429317271941 b_new: 0.05493687953701948
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08459313233181293
# Actualizo pesos y bias
# w1_new: -0.02601524675352441 w2_new:: -0.05278781368486346 b_new: 0.0007072229204288238
# Epocas: 25 SumaErrores: 2.3369880761342623
#
# --- Epoca: 26 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07951028335881669
# Actualizo pesos y bias
# w1_new: 0.027960267414416422 w2_new:: 0.0011877004830773696 b_new: -0.053268291247512006
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08004085817885107
# Actualizo pesos y bias
# w1_new: -0.02604177549452613 w2_new:: 0.05518974339201992 b_new: 0.000733751661430547
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08049776722511551
# Actualizo pesos y bias
# w1_new: 0.027983112866729644 w2_new:: 0.0011648550307641475 b_new: 0.05475864002268632
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08390660792018012
# Actualizo pesos y bias
# w1_new: -0.026212217529279373 w2_new:: -0.05303047536524487 b_new: 0.0005633096266773052
# Epocas: 26 SumaErrores: 2.337079833442316
#
# --- Epoca: 27 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.07980600252120154
# Actualizo pesos y bias
# w1_new: 0.027778082596780704 w2_new:: 0.0009598247608152075 b_new: -0.05342699049938277
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08024524833534827
# Actualizo pesos y bias
# w1_new: -0.026234179819986707 w2_new:: 0.05497208717758262 b_new: 0.0005852719173846388
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.0806209950801847
# Actualizo pesos y bias
# w1_new: 0.027796869934022528 w2_new:: 0.0009410374235733834 b_new: 0.05461632167139387
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08335422902898978
# Actualizo pesos y bias
# w1_new: -0.02637084151742696 w2_new:: -0.053226674027876106 b_new: 0.0004486102199443842
# Epocas: 27 SumaErrores: 2.3371544600975005
#
# --- Epoca: 28 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08004612576524744
# Actualizo pesos y bias
# w1_new: 0.02763146477083541 w2_new:: 0.0007756322603862664 b_new: -0.05355369606831799
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08040952857876713
# Actualizo pesos y bias
# w1_new: -0.02638901165810295 w2_new:: 0.05479610868932463 b_new: 0.0004667803606203738
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08071833998680722
# Actualizo pesos y bias
# w1_new: 0.027646905341237413 w2_new:: 0.0007601916899842645 b_new: 0.05450269735996074
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08290979439118241
# Actualizo pesos y bias
# w1_new: -0.026498584378321713 w2_new:: -0.05338529802957486 b_new: 0.00035720764040161196
# Epocas: 28 SumaErrores: 2.3372150681982538
#
# --- Epoca: 29 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08024109004829819
# Actualizo pesos y bias
# w1_new: 0.0275134701240932 w2_new:: 0.000626756472840051 b_new: -0.0536548468620133
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08054156051326644
# Actualizo pesos y bias
# w1_new: -0.026513607901570126 w2_new:: 0.054653834498503376 b_new: 0.00037223116365002473
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08079521123642348
# Actualizo pesos y bias
# w1_new: 0.027526152660251046 w2_new:: 0.0006140739366822037 b_new: 0.0544119917254712
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08255221832240445
# Actualizo pesos y bias
# w1_new: -0.026601458255869175 w2_new:: -0.05351353697943802 b_new: 0.00028438080935097587
# Epocas: 29 SumaErrores: 2.3372642353257618
#
# --- Epoca: 30 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08039937604465816
# Actualizo pesos y bias
# w1_new: 0.02741851054636374 w2_new:: 0.0005064318227948963 b_new: -0.05373558799288194
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08064766671645078
# Actualizo pesos y bias
# w1_new: -0.026613872789458808 w2_new:: 0.05453881515861744 b_new: 0.00029679534294060894
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08085589260513565
# Actualizo pesos y bias
# w1_new: 0.027428921840797982 w2_new:: 0.0004960205283606536 b_new: 0.0543395899731974
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08226453234235603
# Actualizo pesos y bias
# w1_new: -0.026684304776319827 w2_new:: -0.053617206088757155 b_new: 0.00022636335607958968
# Epocas: 30 SumaErrores: 2.3373040849414295
#
# --- Epoca: 31 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08052787422115656
# Actualizo pesos y bias
# w1_new: 0.027342088934738003 w2_new:: 0.0004091876223006746 b_new: -0.05380003035497824
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08073293166741558
# Actualizo pesos y bias
# w1_new: -0.026694557648632773 w2_new:: 0.05444583420567145 b_new: 0.00023661622839253604
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08090377562591168
# Actualizo pesos y bias
# w1_new: 0.02735063113266281 w2_new:: 0.00040064542437586587 b_new: 0.05428180500968812
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.0820330815667268
# Actualizo pesos y bias
# w1_new: -0.026751022945673525 w2_new:: -0.05370100865396047 b_new: 0.00018015093135178434
# Epocas: 31 SumaErrores: 2.3373363591632383
#
# --- Epoca: 32 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08063218253098578
# Actualizo pesos y bias
# w1_new: 0.02728058618087576 w2_new:: 0.00033060047258881564 b_new: -0.0538514581951975
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08080144390348445
# Actualizo pesos y bias
# w1_new: -0.02675948601429847 w2_new:: 0.05437067266776305 b_new: 0.00018861399997673056
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.0809415446820848
# Actualizo pesos y bias
# w1_new: 0.027287591219805764 w2_new:: 0.00032359543365881316 b_new: 0.054235691234080965
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08184687788754555
# Actualizo pesos y bias
# w1_new: -0.026804752674571518 w2_new:: -0.05376874846071847 b_new: 0.00014334733970368385
# Epocas: 32 SumaErrores: 2.3373624826401302
#
# --- Epoca: 33 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08071684847499368
# Actualizo pesos y bias
# w1_new: 0.027231089749178164 w2_new:: 0.0002670939630312133 b_new: -0.053892495084046
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08085649087019295
# Actualizo pesos y bias
# w1_new: -0.026811734794331486 w2_new:: 0.054309918506540864 b_new: 0.00015032945946365228
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08097132384140869
# Actualizo pesos y bias
# w1_new: 0.02723683139773895 w2_new:: 0.0002613523144704283 b_new: 0.05419889565153409
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08169707936374346
# Actualizo pesos y bias
# w1_new: -0.02684802257044823 w2_new:: -0.05382350165371675 b_new: 0.00011404168334690906
# Epocas: 33 SumaErrores: 2.3373836174527254
#
# --- Epoca: 34 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.0807855659075119
# Actualizo pesos y bias
# w1_new: 0.027191255724927366 w2_new:: 0.00021577664165884497 b_new: -0.053925236612028686
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.0809007156952972
# Actualizo pesos y bias
# w1_new: -0.026853780059837497 w2_new:: 0.05426081242642371 b_new: 0.00011979917273617635
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08099479331352503
# Actualizo pesos y bias
# w1_new: 0.02719595960583876 w2_new:: 0.0002110727607474508 b_new: 0.05416953883841243
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08157657120499864
# Actualizo pesos y bias
# w1_new: -0.02688286895441118 w2_new:: -0.05386775579950249 b_new: 9.071027816249383e-05
# Epocas: 34 SumaErrores: 2.3374007096075693
#
# --- Epoca: 35 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08084133503207616
# Actualizo pesos y bias
# w1_new: 0.027159197797192634 w2_new:: 0.0001743109521013253 b_new: -0.05395135647344132
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08093624331853264
# Actualizo pesos y bias
# w1_new: -0.026887614368734 w2_new:: 0.05422112311802796 b_new: 9.545569248531338e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08101328179427664
# Actualizo pesos y bias
# w1_new: 0.027163049720979833 w2_new:: 0.00017045902831412663 b_new: 0.054146119782199145
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.0814796285314931
# Actualizo pesos y bias
# w1_new: -0.026910931705594825 w2_new:: -0.05390352239826053 b_new: 7.213835562448756e-05
# Epocas: 35 SumaErrores: 2.3374145279888756
#
# --- Epoca: 36 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08088659245947984
# Actualizo pesos y bias
# w1_new: 0.027133397917379176 w2_new:: 0.0001408072247134698 b_new: -0.05397219126734951
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08096478196001522
# Actualizo pesos y bias
# w1_new: -0.02691484118062159 w2_new:: 0.054189046322714235 b_new: 7.604783065125187e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08102783967268458
# Actualizo pesos y bias
# w1_new: 0.027136550803012645 w2_new:: 0.00013765433908000113 b_new: 0.054127439814285486
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08140164495637814
# Actualizo pesos y bias
# w1_new: -0.026933531444806265 w2_new:: -0.05393242790873891 b_new: 5.735756646657597e-05
# Epocas: 36 SumaErrores: 2.3374256967291407
#
# --- Epoca: 37 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08092331692001176
# Actualizo pesos y bias
# w1_new: 0.02711263440119433 w2_new:: 0.00011373793726168757 b_new: -0.05398880827953402
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08098770474346667
# Actualizo pesos y bias
# w1_new: -0.026936750835979004 w2_new:: 0.05416312317443502 b_new: 6.0576957639314755e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08103929705277471
# Actualizo pesos y bias
# w1_new: 0.027115214016659735 w2_new:: 0.00011115832179628415 b_new: 0.05411254181027805
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08133891414873407
# Actualizo pesos y bias
# w1_new: -0.026951731690776977 w2_new:: -0.05395578738564043 b_new: 4.5596102841341524e-05
# Epocas: 37 SumaErrores: 2.337434721946315
#
# --- Epoca: 38 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08095311517925875
# Actualizo pesos y bias
# w1_new: 0.02709592406818597 w2_new:: 9.186837332252062e-05 b_new: -0.054002059656121607
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08100611535098506
# Actualizo pesos y bias
# w1_new: -0.02695438169936329 w2_new:: 0.05414217414087178 b_new: 4.8246111427653615e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08104830972880742
# Actualizo pesos y bias
# w1_new: 0.02709803378707709 w2_new:: 8.975865443140024e-05 b_new: 0.054100661597868034
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08128845403937653
# Actualizo pesos y bias
# w1_new: -0.02696638891489174 w2_new:: -0.05397466404753743 b_new: 3.623889589920298e-05
# Epocas: 38 SumaErrores: 2.337442013724174
#
# --- Epoca: 39 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08097729185832839
# Actualizo pesos y bias
# w1_new: 0.027082475678024687 w2_new:: 7.42005453789954e-05 b_new: -0.05401262569701722
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08102090082966291
# Actualizo pesos y bias
# w1_new: -0.026968569363458463 w2_new:: 0.054125245586862145 b_new: 3.8419344465925875e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08105539560585469
# Actualizo pesos y bias
# w1_new: 0.02708420041683427 w2_new:: 7.247580656941088e-05 b_new: 0.05409118912475866
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08124786534816233
# Actualizo pesos y bias
# w1_new: -0.026978192850573846 w2_new:: -0.053989917460838706 b_new: 2.8795857350542853e-05
# Epocas: 39 SumaErrores: 2.337447904116215
#
# --- Epoca: 40 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.0809969061687631
# Actualizo pesos y bias
# w1_new: 0.027071652457864304 w2_new:: 5.992784759944331e-05 b_new: -0.054021049451087606
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08103277406135247
# Actualizo pesos y bias
# w1_new: -0.026979986245203327 w2_new:: 0.054111566550667074 b_new: 3.0589251980024657e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08106096354389039
# Actualizo pesos y bias
# w1_new: 0.027073061931991195 w2_new:: 5.8518373472551954e-05 b_new: 0.05408363742917455
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.0812152177346383
# Actualizo pesos y bias
# w1_new: -0.02698769895474073 w2_new:: -0.05400224251325937 b_new: 2.2876542442623604e-05
# Epocas: 40 SumaErrores: 2.337452661850313
#
# --- Epoca: 41 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08101281801044272
# Actualizo pesos y bias
# w1_new: 0.02706294194578141 w2_new:: 4.839838726276857e-05 b_new: -0.054027764358079516
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08104230791659817
# Actualizo pesos y bias
# w1_new: -0.026989173450048497 w2_new:: 0.05410051378309268 b_new: 2.4351037750391935e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08106533619539077
# Actualizo pesos y bias
# w1_new: 0.02706409335972105 w2_new:: 4.7246973323131214e-05 b_new: 0.05407761784751994
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08118895818056412
# Actualizo pesos y bias
# w1_new: -0.026995354549307155 w2_new:: -0.05401220093570507 b_new: 1.816993849173415e-05
# Epocas: 41 SumaErrores: 2.3374565043116755
#
# --- Epoca: 42 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08102572542350397
# Actualizo pesos y bias
# w1_new: 0.02705593172186805 w2_new:: 3.908533547013204e-05 b_new: -0.05403311633268347
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08104996271908138
# Actualizo pesos y bias
# w1_new: -0.02699656641408603 w2_new:: 0.05409158347142421 b_new: 1.9381803270608622e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08106876808223965
# Actualizo pesos y bias
# w1_new: 0.02705687199002596 w2_new:: 3.8145067312221614e-05 b_new: 0.0540728202073826
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08116783726472078
# Actualizo pesos y bias
# w1_new: -0.02700151987321009 w2_new:: -0.05402024679592383 b_new: 1.4428344146548422e-05
# Epocas: 42 SumaErrores: 2.337459607290433
#
# --- Epoca: 43 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08103619501328047
# Actualizo pesos y bias
# w1_new: 0.02705028987745394 w2_new:: 3.156295474020243e-05 b_new: -0.05403738140651748
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08105610832923121
# Actualizo pesos y bias
# w1_new: -0.02700251553900762 w2_new:: 0.054084368371201764 b_new: 1.5424009944080275e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08107145990026529
# Actualizo pesos y bias
# w1_new: 0.027051057456005646 w2_new:: 3.079537618849715e-05 b_new: 0.05406899700495735
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08115084983715148
# Actualizo pesos y bias
# w1_new: -0.027006485035851922 w2_new:: -0.05402674711566907 b_new: 1.1454513099778962e-05
# Epocas: 43 SumaErrores: 2.33746211289961
#
# --- Epoca: 44 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08104468666462078
# Actualizo pesos y bias
# w1_new: 0.027045749297379122 w2_new:: 2.548721756197303e-05 b_new: -0.054040779820131266
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08106104189994842
# Actualizo pesos y bias
# w1_new: -0.0270073027976183 w2_new:: 0.0540785393125594 b_new: 1.2272274866158284e-05
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08107356983531153
# Actualizo pesos y bias
# w1_new: 0.02704637569414728 w2_new:: 2.4860820793816407e-05 b_new: 0.05406595076663174
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08113718728157283
# Actualizo pesos y bias
# w1_new: -0.02701048366993137 w2_new:: -0.05403199854328483 b_new: 9.091402553090822e-06
# Epocas: 44 SumaErrores: 2.3374641359995927
#
# --- Epoca: 45 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08105157361576928
# Actualizo pesos y bias
# w1_new: 0.027042095010857102 w2_new:: 2.058013750363963e-05 b_new: -0.05404348727823538
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08106500215158885
# Actualizo pesos y bias
# w1_new: -0.02701115509672234 w2_new:: 0.05407383024508308 b_new: 9.76282934406214e-06
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08107522251246135
# Actualizo pesos y bias
# w1_new: 0.027042606028900733 w2_new:: 2.006911946000889e-05 b_new: 0.054063523954967135
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08112619910332788
# Actualizo pesos y bias
# w1_new: -0.02701370392626566 w2_new:: -0.054036240835706385 b_new: 7.2139998007411665e-06
# Epocas: 45 SumaErrores: 2.337465769406061
#
# --- Epoca: 46 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.0810571587617728
# Actualizo pesos y bias
# w1_new: 0.027039154011822983 w2_new:: 1.661710238225894e-05 b_new: -0.0540456439382879
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08106818084772863
# Actualizo pesos y bias
# w1_new: -0.027014255030563455 w2_new:: 0.0540700261447687 b_new: 7.765104098535203e-06
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08107651607123362
# Actualizo pesos y bias
# w1_new: 0.027039570772998234 w2_new:: 1.620034120700803e-05 b_new: 0.054061590907660224
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08111736202186547
# Actualizo pesos y bias
# w1_new: -0.027016297328095046 w2_new:: -0.05403966775988627 b_new: 5.722806566944849e-06
# Epocas: 46 SumaErrores: 2.3374670881086637
#
# --- Epoca: 47 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08106168789454826
# Actualizo pesos y bias
# w1_new: 0.027036787066632373 w2_new:: 1.3416634841147135e-05 b_new: -0.054047361588160474
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.0810707320199517
# Actualizo pesos y bias
# w1_new: -0.02701674953436522 w2_new:: 0.05406695323583874 b_new: 6.175012837117411e-06
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08107752775736685
# Actualizo pesos y bias
# w1_new: 0.027037126853503124 w2_new:: 1.3076847970396044e-05 b_new: 0.05406005140070546
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08111025510217898
# Actualizo pesos y bias
# w1_new: -0.027018385901605824 w2_new:: -0.05404243590713855 b_new: 4.538645596512125e-06
# Epocas: 47 SumaErrores: 2.3374681526863217
#
# --- Epoca: 48 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.0810653604543409
# Actualizo pesos y bias
# w1_new: 0.02703488212111123 w2_new:: 1.0832115578500445e-05 b_new: -0.05404872937712054
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08107277938265327
# Actualizo pesos y bias
# w1_new: -0.027018756848021443 w2_new:: 0.05406447108471117 b_new: 4.909592012131148e-06
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08107831834072049
# Actualizo pesos y bias
# w1_new: 0.027035159069014582 w2_new:: 1.055516767514697e-05 b_new: 0.054058825509048156
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08110453974573789
# Actualizo pesos y bias
# w1_new: -0.02702006791827232 w2_new:: -0.054044671819611756 b_new: 3.5985217612527487e-06
# Epocas: 48 SumaErrores: 2.3374690120708266
#
# --- Epoca: 49 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08106833825964534
# Actualizo pesos y bias
# w1_new: 0.027033348994709945 w2_new:: 8.745093370510215e-06 b_new: -0.05404981839122101
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.08107442229256046
# Actualizo pesos y bias
# w1_new: -0.027020372119918083 w2_new:: 0.05406246620799854 b_new: 3.902723407014919e-06
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08107893560450961
# Actualizo pesos y bias
# w1_new: 0.027033574660307404 w2_new:: 8.519427773051591e-06 b_new: 0.0540578495036325
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.08109994359171296
# Actualizo pesos y bias
# w1_new: -0.02702142251927825 w2_new:: -0.0540464777518126 b_new: 2.852324046849486e-06
# Epocas: 49 SumaErrores: 2.3374697057822247
#
# --- Epoca: 50 ---
# Iteracion: 1
# num1: -1 num2: -1
# Y: 0.08107075259513769
# Actualizo pesos y bias
# w1_new: 0.027032115110478643 w2_new:: 7.059877944290416e-06 b_new: -0.05405068530571004
# Iteracion: 2
# num1: -1 num2: 1
# Y: -0.0810757405382444
# Actualizo pesos y bias
# w1_new: -0.027021671916433572 w2_new:: 0.054060846904856505 b_new: 3.1017212021727802e-06
# Iteracion: 3
# num1: 1 num2: -1
# Y: -0.08107941710008791
# Actualizo pesos y bias
# w1_new: 0.02703229893857083 w2_new:: 6.876049852104493e-06 b_new: 0.05405707257620657
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.0810962475646295
# Actualizo pesos y bias
# w1_new: -0.027022513439660653 w2_new:: -0.05404793632837938 b_new: 2.260197975091638e-06
# Epocas: 50 SumaErrores: 2.3374702657363597

# %%
# Crear la gráfica de el error cuadrático medio por epoca
epocas = range(1, len(error) + 1)
plt.plot(epocas, error, marker='o', linestyle='-', color='b')  # Línea con puntos marcados
plt.title('Error cuadrático medio (LMS) por Época')  # Título de la gráfica
plt.xlabel('Época')  # Etiqueta del eje X
plt.ylabel('Error cuadrático medio')  # Etiqueta del eje Y
plt.grid(True)  # Agregar una cuadrícula para mejor visualización
plt.xticks(epocas)  # Asegurar que las épocas se muestren correctamente en el eje X
plt.show()  # Mostrar la gráfica

# %%
def validar_entrada(mensaje):
    while True:
        try:
            valor = float(input(mensaje))
            if -1 <= valor <= 1:
                return valor
            else:
                print("Error: El valor debe estar entre -1 y 1. Intente nuevamente.")
        except ValueError:
            print("Error: Ingrese un número válido.")

# Datos de ejemplo (simulando tus datos)
# atributos     ->   [x1, x2]
individuo = np.array([[-1, -1], 
                      [-1, 1],  
                      [1, -1], 
                      [1, 1],
                     ])
# 1 : true    -1 : false
clases = np.array([-1, 1, 1, -1])
# Crear la figura
plt.figure(figsize=(6, 5), dpi=200)
plt.title("Adaline con su recta de clasificacion", fontsize=15)

# Graficar los puntos de entrada
plt.scatter(individuo[clases == -1].T[0], 
            individuo[clases == -1].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="False")
plt.scatter(individuo[clases == 1].T[0],
            individuo[clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")

# Generar y graficar la región de decisión
for x1 in np.arange(-1, 1.05, 0.05):
    for x2 in np.arange(-1, 1.05, 0.05):
        # Calcular el valor de y
        y = (w1 * x1) + (w2 * x2) + b
        
        # Función de activación
        if y >= 0:
            color = "blue"  # Clase 1
        else:
            color = "red"   # Clase 0
        
        # Graficar el punto
        plt.scatter(x1, x2, marker="s", s=110,
                    color=color, alpha=0.2, linewidths=0)

# Calcular puntos para la recta (usando la ecuación w1*x1 + w2*x2 + b = 0)
x1_vals = np.array([-1.5, 1.5])  # Rango amplio para graficar
x2_vals = (-w1 * x1_vals - b) / w2  # Despejamos x2 de la ecuación

# Graficar la recta de decisión
plt.plot(x1_vals, x2_vals, color="green", linestyle="--", linewidth=2, label="Recta clasificadora")

# Solicitar valores de x1 y x2 al usuario
x1 = validar_entrada("Ingrese x1 con un valor entre -1 y 1: ")
x2 = validar_entrada("Ingrese x2 con un valor entre -1 y 1: ")

# Determinar la clase del punto ingresado
y = (w1 * x1) + (w2 * x2) + b
if y >= 0:
    color = "blue"  # Clase 1
else:
    color = "red"   # Clase -1

# Graficar el punto ingresado
plt.scatter(x1, x2, marker="*", s=200, color=color, label="Punto ingresado")

# Configuraciones adicionales del gráfico
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.show()
# Out:
# Ingrese x1 con un valor entre -1 y 1:  0.6
# Ingrese x2 con un valor entre -1 y 1:  0.6
