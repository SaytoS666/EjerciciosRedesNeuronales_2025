# %%
import numpy as np
import matplotlib.pyplot as plt

#                ->   [x1,    x2]
individuo = np.array([[0.5,  0.5],       
                      [0.1,  0.2],      
                      [0.7,  0.9],      
                      [0.85,0.85],    
                              ])

# pesos    se pueden cambiar
w =np.array( [[0.7, 0.3, 0.5, 0.6, 0.1], # pesos para x1
              [0.1, 0.9, 0.6, 0.9, 0.1], # pesos para x2
                        ])
# Parámetro de aprendizaje
pa = 0.2

# Número de épocas
num_epocas = 5

# Tamaño de la matriz de pesos
num_neuronas = w.shape[1]  # 5 neuronas
longitud = num_neuronas - 1  # 4 (índice máximo)

for epoca in range(num_epocas):
    print(f"\n--- Época {epoca + 1} ---")
    
    for i in range(len(individuo)):
        print(f"\nProcesando individuo {i}: {individuo[i]}")
        
        # 1. Calcular distancias euclidianas entre el individuo y todas las neuronas
        distancias = []
        for j in range(num_neuronas):
            dx = w[0, j] - individuo[i, 0]
            dy = w[1, j] - individuo[i, 1]
            D = dx**2 + dy**2  # Distancia euclidiana al cuadrado
            distancias.append(D)
        
        print("Distancias calculadas:", distancias)
        
        # 2. Encontrar la neurona ganadora (menor distancia)
        indice_min = np.argmin(distancias)
        valor_min = distancias[indice_min]
        print(f"Neurona ganadora: índice {indice_min}, distancia {valor_min:.4f}")
        
        # 3. Actualizar pesos: neurona ganadora y sus vecinas
        if indice_min == 0:
            print("Caso: neurona ganadora es la primera (índice 0)")
            # Actualizar neurona ganadora (0) y su vecina derecha (1)
            for k in [0, 1]:
                w[0, k] += pa * (individuo[i, 0] - w[0, k])
                w[1, k] += pa * (individuo[i, 1] - w[1, k])
                
        elif indice_min == longitud:
            print(f"Caso: neurona ganadora es la última (índice {longitud})")
            # Actualizar neurona ganadora (longitud) y su vecina izquierda (longitud-1)
            for k in [longitud, longitud-1]:
                w[0, k] += pa * (individuo[i, 0] - w[0, k])
                w[1, k] += pa * (individuo[i, 1] - w[1, k])
                
        else:
            print(f"Caso: neurona ganadora es intermedia (índice {indice_min})")
            # Actualizar neurona ganadora y sus dos vecinas (izquierda y derecha)
            for k in [indice_min-1, indice_min, indice_min+1]:
                w[0, k] += pa * (individuo[i, 0] - w[0, k])
                w[1, k] += pa * (individuo[i, 1] - w[1, k])
        
        print("Pesos actualizados:")
        print(w)

print("\n--- Pesos finales ---")
print(w)
# Out:
# --- Época 1 ---
#
# Procesando individuo 0: [0.5 0.5]
# Distancias calculadas: [0.2, 0.20000000000000004, 0.009999999999999995, 0.17000000000000004, 0.32000000000000006]
# Neurona ganadora: índice 2, distancia 0.0100
# Caso: neurona ganadora es intermedia (índice 2)
# Pesos actualizados:
# [[0.7  0.34 0.5  0.58 0.1 ]
#  [0.1  0.82 0.58 0.82 0.1 ]]
#
# Procesando individuo 1: [0.1 0.2]
# Distancias calculadas: [0.37, 0.4420000000000001, 0.3044, 0.6148000000000001, 0.010000000000000002]
# Neurona ganadora: índice 4, distancia 0.0100
# Caso: neurona ganadora es la última (índice 4)
# Pesos actualizados:
# [[0.7   0.34  0.5   0.484 0.1  ]
#  [0.1   0.82  0.58  0.696 0.12 ]]
#
# Procesando individuo 2: [0.7 0.9]
# Distancias calculadas: [0.6400000000000001, 0.13599999999999998, 0.14240000000000003, 0.08827199999999998, 0.9684]
# Neurona ganadora: índice 3, distancia 0.0883
# Caso: neurona ganadora es intermedia (índice 3)
# Pesos actualizados:
# [[0.7    0.34   0.54   0.5272 0.22  ]
#  [0.1    0.82   0.644  0.7368 0.276 ]]
#
# Procesando individuo 3: [0.85 0.85]
# Distancias calculadas: [0.585, 0.261, 0.13853599999999994, 0.11701407999999998, 0.7263759999999999]
# Neurona ganadora: índice 3, distancia 0.1170
# Caso: neurona ganadora es intermedia (índice 3)
# Pesos actualizados:
# [[0.7     0.34    0.602   0.59176 0.346  ]
#  [0.1     0.82    0.6852  0.75944 0.3908 ]]
#
# --- Época 2 ---
#
# Procesando individuo 0: [0.5 0.5]
# Distancias calculadas: [0.2, 0.12800000000000006, 0.044703040000000006, 0.07572901119999999, 0.03564064]
# Neurona ganadora: índice 4, distancia 0.0356
# Caso: neurona ganadora es la última (índice 4)
# Pesos actualizados:
# [[0.7      0.34     0.602    0.573408 0.3768  ]
#  [0.1      0.82     0.6852   0.707552 0.41264 ]]
#
# Procesando individuo 1: [0.1 0.2]
# Distancias calculadas: [0.37, 0.4420000000000001, 0.48742304000000003, 0.48172416716799993, 0.12183400959999996]
# Neurona ganadora: índice 4, distancia 0.1218
# Caso: neurona ganadora es la última (índice 4)
# Pesos actualizados:
# [[0.7       0.34      0.602     0.4787264 0.32144  ]
#  [0.1       0.82      0.6852    0.6060416 0.370112 ]]
#
# Procesando individuo 2: [0.7 0.9]
# Distancias calculadas: [0.6400000000000001, 0.13599999999999998, 0.055743039999999994, 0.13537354698752005, 0.42408896614400005]
# Neurona ganadora: índice 2, distancia 0.0557
# Caso: neurona ganadora es intermedia (índice 2)
# Pesos actualizados:
# [[0.7        0.412      0.6216     0.52298112 0.32144   ]
#  [0.1        0.836      0.72816    0.66483328 0.370112  ]]
#
# Procesando individuo 3: [0.85 0.85]
# Distancias calculadas: [0.585, 0.19204, 0.06701154560000001, 0.1412280620720128, 0.509668166144]
# Neurona ganadora: índice 2, distancia 0.0670
# Caso: neurona ganadora es intermedia (índice 2)
# Pesos actualizados:
# [[0.7        0.4996     0.66728    0.5883849  0.32144   ]
#  [0.1        0.8388     0.752528   0.70186662 0.370112  ]]
#
# --- Época 3 ---
#
# Procesando individuo 0: [0.5 0.5]
# Distancias calculadas: [0.2, 0.11478560000000007, 0.09175298918399999, 0.048562023726088185, 0.04875456614400002]
# Neurona ganadora: índice 3, distancia 0.0486
# Caso: neurona ganadora es intermedia (índice 3)
# Pesos actualizados:
# [[0.7        0.4996     0.633824   0.57070792 0.357152  ]
#  [0.1        0.8388     0.7020224  0.6614933  0.3960896 ]]
#
# Procesando individuo 1: [0.1 0.2]
# Distancias calculadas: [0.37, 0.5677456000000001, 0.53699455307776, 0.43454200814469646, 0.10457828233215996]
# Neurona ganadora: índice 4, distancia 0.1046
# Caso: neurona ganadora es la última (índice 4)
# Pesos actualizados:
# [[0.7        0.4996     0.633824   0.47656633 0.3057216 ]
#  [0.1        0.8388     0.7020224  0.56919464 0.35687168]]
#
# Procesando individuo 2: [0.7 0.9]
# Distancias calculadas: [0.6400000000000001, 0.043905599999999975, 0.04357439307776004, 0.1593547899806057, 0.4504438286925825]
# Neurona ganadora: índice 2, distancia 0.0436
# Caso: neurona ganadora es intermedia (índice 2)
# Pesos actualizados:
# [[0.7        0.53968    0.6470592  0.52125307 0.3057216 ]
#  [0.1        0.85104    0.74161792 0.63535571 0.35687168]]
#
# Procesando individuo 3: [0.85 0.85]
# Distancias calculadas: [0.585, 0.09629958400000002, 0.05293164356976642, 0.1541467167107876, 0.5394145166925824]
# Neurona ganadora: índice 2, distancia 0.0529
# Caso: neurona ganadora es intermedia (índice 2)
# Pesos actualizados:
# [[0.7        0.601744   0.68764736 0.58700245 0.3057216 ]
#  [0.1        0.850832   0.76329434 0.67828457 0.35687168]]
#
# --- Época 4 ---
#
# Procesando individuo 0: [0.5 0.5]
# Distancias calculadas: [0.2, 0.1334349337600001, 0.10453543908465045, 0.03935481450930411, 0.058229812692582414]
# Neurona ganadora: índice 3, distancia 0.0394
# Caso: neurona ganadora es intermedia (índice 3)
# Pesos actualizados:
# [[0.7        0.601744   0.65011789 0.56960196 0.34457728]
#  [0.1        0.850832   0.71063547 0.64262766 0.38549734]]
#
# Procesando individuo 1: [0.1 0.2]
# Distancias calculadas: [0.37, 0.6753293337600002, 0.5633782726941762, 0.4164452446743706, 0.09422731052325271]
# Neurona ganadora: índice 4, distancia 0.0942
# Caso: neurona ganadora es la última (índice 4)
# Pesos actualizados:
# [[0.7        0.601744   0.65011789 0.47568157 0.29566182]
#  [0.1        0.850832   0.71063547 0.55410212 0.34839788]]
#
# Procesando individuo 2: [0.7 0.9]
# Distancias calculadas: [0.6400000000000001, 0.012071733759999991, 0.038347150774176345, 0.16996409838457002, 0.4677542646548818]
# Neurona ganadora: índice 1, distancia 0.0121
# Caso: neurona ganadora es intermedia (índice 1)
# Pesos actualizados:
# [[0.7        0.6213952  0.66009431 0.47568157 0.29566182]
#  [0.26       0.8606656  0.74850838 0.55410212 0.34839788]]
#
# Procesando individuo 3: [0.85 0.85]
# Distancias calculadas: [0.3706, 0.052373909606400024, 0.04636472087947287, 0.22766983975964838, 0.5588955049748818]
# Neurona ganadora: índice 2, distancia 0.0464
# Caso: neurona ganadora es intermedia (índice 2)
# Pesos actualizados:
# [[0.7        0.66711616 0.69807545 0.55054526 0.29566182]
#  [0.26       0.85853248 0.7688067  0.6132817  0.34839788]]
#
# --- Época 5 ---
#
# Procesando individuo 0: [0.5 0.5]
# Distancias calculadas: [0.09759999999999998, 0.1564733501480961, 0.1114909252092626, 0.015387566343147783, 0.06473729441488177]
# Neurona ganadora: índice 3, distancia 0.0154
# Caso: neurona ganadora es intermedia (índice 3)
# Pesos actualizados:
# [[0.7        0.66711616 0.65846036 0.5404362  0.33652946]
#  [0.26       0.85853248 0.71504536 0.59062536 0.3787183 ]]
#
# Procesando individuo 1: [0.1 0.2]
# Distancias calculadas: [0.3636, 0.7552857661480961, 0.577149695074088, 0.3465722221144836, 0.0878864158815243]
# Neurona ganadora: índice 4, distancia 0.0879
# Caso: neurona ganadora es la última (índice 4)
# Pesos actualizados:
# [[0.7        0.66711616 0.65846036 0.45234896 0.28922357]
#  [0.26       0.85853248 0.71504536 0.51250029 0.34297464]]
#
# Procesando individuo 2: [0.7 0.9]
# Distancias calculadas: [0.4096, 0.0028009021480959887, 0.035933760651048065, 0.21148706275127158, 0.4790145291529756]
# Neurona ganadora: índice 1, distancia 0.0028
# Caso: neurona ganadora es intermedia (índice 1)
# Pesos actualizados:
# [[0.7        0.67369293 0.66676829 0.45234896 0.28922357]
#  [0.388      0.86682598 0.75203629 0.51250029 0.34297464]]
#
# Procesando individuo 3: [0.85 0.85]
# Distancias calculadas: [0.235944, 0.031367297374781465, 0.043170749541278766, 0.2720324023353117, 0.5715449229577756]
# Neurona ganadora: índice 1, distancia 0.0314
# Caso: neurona ganadora es intermedia (índice 1)
# Pesos actualizados:
# [[0.73       0.70895434 0.70341463 0.45234896 0.28922357]
#  [0.4804     0.86346079 0.77162903 0.51250029 0.34297464]]
#
# --- Pesos finales ---
# [[0.73       0.70895434 0.70341463 0.45234896 0.28922357]
#  [0.4804     0.86346079 0.77162903 0.51250029 0.34297464]]

# %%
# Código adicional para visualización
plt.figure(figsize=(10, 6))

# Graficar los datos originales
plt.scatter(individuo[:, 0], individuo[:, 1], c='blue', label='Datos originales', s=100, alpha=0.6)

# Graficar los pesos finales de las neuronas
plt.scatter(w[0, :], w[1, :], c='red', marker='X', label='Neuronas SOM', s=150)

# Conectar las neuronas para mostrar la topología
plt.plot(w[0, :], w[1, :], 'g--', alpha=0.3, label='Topología SOM')

# Asignar cada punto a su neurona ganadora y colorear
for i in range(len(individuo)):
    distancias = [np.linalg.norm(individuo[i] - w[:, j]) for j in range(num_neuronas)]
    neurona_ganadora = np.argmin(distancias)
    plt.plot([individuo[i, 0], w[0, neurona_ganadora]], 
             [individuo[i, 1], w[1, neurona_ganadora]], 
             'k:', alpha=0.4)
    
    # Colorear según la neurona ganadora
    plt.scatter(individuo[i, 0], individuo[i, 1], c=f'C{neurona_ganadora}', s=100)

plt.title('Resultados del SOM - Asignación de Clusters')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.grid(True)
plt.show()
