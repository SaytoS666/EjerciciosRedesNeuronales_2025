# %%
import numpy as np
import matplotlib.pyplot as plt

#                ->   [x1,    x2]
individuo = np.array([[1, 1],       
                      [2, 2],      
                      [8, 8],      
                      [9, 9], 
                              ])

clases = np.array([0, 0, 1, 1])

# pesos    se pueden cambiar
w =np.array([    [1.5, 8.5],  # Valores x1: promedio de cada clase
                 [1.5, 8.5]   # Valores x2: promedio de cada clase
                        ])
# Parámetro de aprendizaje
pa = 0.01

# Número de épocas
num_epocas = 10

# Tamaño de la matriz de pesos
num_neuronas = w.shape[1]  # 5 neuronas
longitud = num_neuronas - 1  # 4 (índice máximo)

for epoca in range(num_epocas):
    print(f"\n--- Época {epoca + 1} ---")
    
    for i in range(len(individuo)):
        print(f"\nProcesando individuo {i}: {individuo[i]}  clase {i}: {clases[i]}"  )
        
        # 1. Calcular distancias euclidianas entre el individuo y todas las neuronas
        distancias = []
        for j in range(num_neuronas):
            dx = w[0, j] - individuo[i, 0]
            dy = w[1, j] - individuo[i, 1]
            D = dx**2 + dy**2  # Distancia euclidiana al cuadrado
            distancias.append(D)
        
        print("Distancias calculadas:", distancias)
        
        # 2. Encontrar la neurona ganadora (menor distancia)
        indice_min = np.argmin(distancias)
        valor_min = distancias[indice_min]
        print(f"Neurona ganadora: índice {indice_min}, distancia {valor_min:.4f}")
        
        # 3. Comparamos si el valor minimo es igual a la clase en curso
        if valor_min == clases[i]:
            print("La neurona ganadora CORRESPONDE a la clase del dato (mover hacia el patrón)")
            # Actualización positiva (acercar pesos al dato)
            w[0, indice_min] += pa * (individuo[i, 0] - w[0, indice_min])
            w[1, indice_min] += pa * (individuo[i, 1] - w[1, indice_min])
        else:
            print("La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)")
            # Actualización negativa (alejar pesos del dato)
            w[0, indice_min] -= pa * (individuo[i, 0] - w[0, indice_min])
            w[1, indice_min] -= pa * (individuo[i, 1] - w[1, indice_min])
        
        print("Pesos actualizados:")
        print(w)

print("\n--- Pesos finales ---")
print(w)
# Out:
# --- Época 1 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.5, 112.5]
# Neurona ganadora: índice 0, distancia 0.5000
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.505 8.5  ]
#  [1.505 8.5  ]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.4900500000000002, 84.5]
# Neurona ganadora: índice 0, distancia 0.4901
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50005 8.5    ]
#  [1.50005 8.5    ]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.498700005, 0.5]
# Neurona ganadora: índice 1, distancia 0.5000
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50005 8.505  ]
#  [1.50005 8.505  ]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.498500005, 0.49004999999999843]
# Neurona ganadora: índice 1, distancia 0.4900
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50005 8.50005]
#  [1.50005 8.50005]]
#
# --- Época 2 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.5001000049999997, 112.50150000500005]
# Neurona ganadora: índice 0, distancia 0.5001
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.5050505 8.50005  ]
#  [1.5050505 8.50005  ]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.4899500151005003, 84.50130000500005]
# Neurona ganadora: índice 0, distancia 0.4900
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.500101 8.50005 ]
#  [1.500101 8.50005 ]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.49737389040403, 0.5001000050000033]
# Neurona ganadora: índice 1, distancia 0.5001
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.500101  8.5050505]
#  [1.500101  8.5050505]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.49696987040404, 0.4899500151004977]
# Neurona ganadora: índice 1, distancia 0.4900
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.500101   8.50010101]
#  [1.500101   8.50010101]]
#
# --- Época 3 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.5002020304040198, 112.50303017040406]
# Neurona ganadora: índice 0, distancia 0.5002
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50510202 8.50010101]
#  [1.50510202 8.50010101]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.4898480310151411, 84.50262615040405]
# Neurona ganadora: índice 0, distancia 0.4898
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50015304 8.50010101]
#  [1.50015304 8.50010101]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.49602113162656, 0.5002020304040224]
# Neurona ganadora: índice 1, distancia 0.5002
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50015304 8.50510202]
#  [1.50015304 8.50510202]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.49540899082456, 0.4898480310151385]
# Neurona ganadora: índice 1, distancia 0.4898
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50015304 8.50015304]
#  [1.50015304 8.50015304]]
#
# --- Época 4 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.500306117240545, 112.50459110285458]
# Neurona ganadora: índice 0, distancia 0.5003
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50515457 8.50015304]
#  [1.50515457 8.50015304]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.4897440079870603, 84.50397896205257]
# Neurona ganadora: índice 0, distancia 0.4897
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50020611 8.50015304]
#  [1.50020611 8.50015304]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.49464119355488, 0.5003061172405476]
# Neurona ganadora: índice 1, distancia 0.5003
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50020611 8.50515457]
#  [1.50020611 8.50515457]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.49381674872276, 0.4897440079870594]
# Neurona ganadora: índice 1, distancia 0.4897
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50020611 8.50020611]
#  [1.50020611 8.50020611]]
#
# --- Época 5 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.5004123073797202, 112.50618342120455]
# Neurona ganadora: índice 0, distancia 0.5004
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50520817 8.50020611]
#  [1.50520817 8.50020611]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.4896379054776114, 84.50535897637243]
# Neurona ganadora: índice 0, distancia 0.4896
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50026025 8.50020611]
#  [1.50026025 8.50020611]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.49323353033823, 0.5004123073797198]
# Neurona ganadora: índice 1, distancia 0.5004
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50026025 8.50520817]
#  [1.50026025 8.50520817]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.49219251416498, 0.4896379054776122]
# Neurona ganadora: índice 1, distancia 0.4896
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50026025 8.50026025]
#  [1.50026025 8.50026025]]
#
# --- Época 6 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.5005206435509569, 112.50780775676368]
# Neurona ganadora: índice 0, distancia 0.5005
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50526286 8.50026025]
#  [1.50526286 8.50026025]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.4895296821513532, 84.50676674059044]
# Neurona ganadora: índice 0, distancia 0.4895
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50031549 8.50026025]
#  [1.50031549 8.50026025]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.49179758517265, 0.5005206435509574]
# Neurona ganadora: índice 1, distancia 0.5005
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50031549 8.50526286]
#  [1.50031549 8.50526286]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.49053564457432, 0.4895296821513532]
# Neurona ganadora: índice 1, distancia 0.4895
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50031549 8.50031549]
#  [1.50031549 8.50031549]]
#
# --- Época 7 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.500631169360923, 112.50946475354921]
# Neurona ganadora: índice 0, distancia 0.5006
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50531864 8.50031549]
#  [1.50531864 8.50031549]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.4894192958607669, 84.50820281295088]
# Neurona ganadora: índice 0, distancia 0.4894
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50037183 8.50031549]
#  [1.50037183 8.50031549]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.49033279008145, 0.5006311693609221]
# Neurona ganadora: índice 1, distancia 0.5006
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50037183 8.50531864]
#  [1.50037183 8.50531864]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.4888454844771, 0.4894192958607682]
# Neurona ganadora: índice 1, distancia 0.4894
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50037183 8.50037183]
#  [1.50037183 8.50037183]]
#
# --- Época 8 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.5007439293119218, 112.51115506854237]
# Neurona ganadora: índice 0, distancia 0.5007
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50537554 8.50037183]
#  [1.50537554 8.50037183]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.4893067036306947, 84.50966776293802]
# Neurona ganadora: índice 0, distancia 0.4893
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.5004293  8.50037183]
#  [1.5004293  8.50037183]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.48883856569167, 0.50074392931192]
# Neurona ganadora: índice 1, distancia 0.5007
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.5004293  8.50537554]
#  [1.5004293  8.50537554]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.48712136524466, 0.4893067036306973]
# Neurona ganadora: índice 1, distancia 0.4893
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.5004293 8.5004293]
#  [1.5004293 8.5004293]]
#
# --- Época 9 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.5008589688206722, 112.51287937194965]
# Neurona ganadora: índice 0, distancia 0.5009
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50543359 8.5004293 ]
#  [1.50543359 8.5004293 ]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.48919186164249695, 84.51116217150265]
# Neurona ganadora: índice 0, distancia 0.4892
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50048793 8.5004293 ]
#  [1.50048793 8.5004293 ]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.48731432100561, 0.5008589688206704]
# Neurona ganadora: índice 1, distancia 0.5009
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50048793 8.50543359]
#  [1.50048793 8.50543359]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.48536260482962, 0.48919186164249784]
# Neurona ganadora: índice 1, distancia 0.4892
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50048793 8.50048793]
#  [1.50048793 8.50048793]]
#
# --- Época 10 ---
#
# Procesando individuo 0: [1 1]  clase 0: 0
# Distancias calculadas: [0.5009763342374965, 112.51463834746936]
# Neurona ganadora: índice 0, distancia 0.5010
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50549281 8.50048793]
#  [1.50549281 8.50048793]]
#
# Procesando individuo 1: [2 2]  clase 1: 0
# Distancias calculadas: [0.48907472521792505, 84.51268663129338]
# Neurona ganadora: índice 0, distancia 0.4891
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50054774 8.50048793]
#  [1.50054774 8.50048793]]
#
# Procesando individuo 2: [8 8]  clase 2: 1
# Distancias calculadas: [84.48575945316806, 0.5009763342374943]
# Neurona ganadora: índice 1, distancia 0.5010
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50054774 8.50549281]
#  [1.50054774 8.50549281]]
#
# Procesando individuo 3: [9 9]  clase 3: 1
# Distancias calculadas: [112.48356850749694, 0.489074725217929]
# Neurona ganadora: índice 1, distancia 0.4891
# La neurona ganadora NO CORRESPONDE a la clase del dato (alejar del patrón)
# Pesos actualizados:
# [[1.50054774 8.50054774]
#  [1.50054774 8.50054774]]
#
# --- Pesos finales ---
# [[1.50054774 8.50054774]
#  [1.50054774 8.50054774]]

# %%
plt.figure(figsize=(10, 6))

# Graficar los datos originales coloreados por su clase verdadera
for clase in np.unique(clases):
    mask = clases == clase
    plt.scatter(individuo[mask, 0], individuo[mask, 1], 
                c=f'C{clase}',  # Cambiado de clase-1 a clase (ya que empiezan en 0)
                label=f'Clase {clase}', s=100, alpha=0.6)

# Graficar los pesos/prototipos
plt.scatter(w[0, :], w[1, :], c='red', marker='X', s=200, label='Prototipos LVQ')

# Etiquetar cada prototipo
for j in range(w.shape[1]):
    plt.text(w[0, j], w[1, j], f'P{j+1}', ha='center', va='bottom', fontweight='bold')

# Conectar puntos a sus prototipos ganadores
for i in range(len(individuo)):
    distancias = [np.linalg.norm(individuo[i] - w[:, j]) for j in range(w.shape[1])]
    prototipo_ganador = np.argmin(distancias)
    plt.plot([individuo[i, 0], w[0, prototipo_ganador]], 
             [individuo[i, 1], w[1, prototipo_ganador]], 
             'k:', alpha=0.4)

plt.title('Resultados del LVQ - Asignación a Prototipos')
plt.xlabel('x1')
plt.ylabel('x2')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Predecir clases basado en prototipos más cercanos
predicciones = []
for i in range(len(individuo)):
    distancias = [np.linalg.norm(individuo[i] - w[:, j]) for j in range(w.shape[1])]
    predicciones.append(np.argmin(distancias) + 1)  # +1 si tus clases comienzan en 1

# Matriz de confusión
cm = confusion_matrix(clases, predicciones)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=np.unique(clases), 
            yticklabels=np.unique(clases))
plt.title('Matriz de Confusión LVQ')
plt.xlabel('Predicción')
plt.ylabel('Verdadero')
plt.show()
