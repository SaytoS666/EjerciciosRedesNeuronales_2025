# %%
# Este codigo solo muestra los puntos clasifiacados segun su clase
import numpy as np
import matplotlib.pyplot as plt

# atributos     ->   [x1, x2]
individuo = np.array([[0, 0], 
                      [0, 1],  
                      [1, 0], 
                      [1, 1],
                     ])
# 1 : true    0 : false
clases = np.array([0, 0, 0, 1])

# Gráfica de dispersión (x1, x2)
plt.figure(figsize=(7, 7))
plt.title("Data SET", fontsize=20)
plt.scatter(individuo [clases == 0].T[0], 
            individuo [clases == 0].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="false")
plt.scatter(individuo [clases == 1].T[0],
            individuo [clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.grid()
plt.show()

# %%
# Este codigo ejecuta las epocas definidas en el while.

# pesos    se pueden cambiar
w1 = 0.2
w2 = 0.2
# bias   se puede cambiar
b = 0.2
# α parámetro de aprendizaje  se puede cambiar
pa = 0.1
numEpocas=50 # **aqui se cambia el numero de epocas**
# épocas 
epocas = 0
# guarda la suma de los errores por iteracion y vuelve a 0 al incio de cada epoca
sumaErrores=0
# se guarda el error por epoca
error= []
# contaSinError = 0
longitud = len(clases)
# guarda los aciertos de cada epoca
# aciertos = []
while epocas != numEpocas:   
    print("\n--- Epoca:", epocas+1, "---")
    for i in range(individuo.shape[0]):
        print("Iteracion:", i + 1)  # Imprimir el índice de la fila
        print("num1:", individuo[i, 0], "num2:", individuo[i, 1])
        y = (w1 * individuo[i, 0]) + (w2 * individuo[i, 1]) + b
        print("Y:", y)

        # Verificar si la predicción es correcta
        if y == clases[i]:
            print("No actualizo pesos, ni bias")
            #contaSinError += 1
        else:
            print("Actualizo pesos y bias")
            w1 = w1 + pa * (clases[i]-y) * individuo[i, 0]
            w2 = w2 + pa * (clases[i]-y) * individuo[i, 1]
            b = b + pa * (clases[i]-y)
            print("w1_new:", w1, "w2_new::", w2, "b_new:", b)
            # calculo el error en la iteracion correpondiente
            sumaErrores=(((clases[i]-y) ** 2) /2)+sumaErrores
    # Incrementar épocas después de recorrer todos los individuos
    epocas += 1
    print("Epocas:", epocas, "SumaErrores:", sumaErrores)
    error.append(sumaErrores)
    sumaErrores = 0
# Out:
# --- Epoca: 1 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: 0.2
# Actualizo pesos y bias
# w1_new: 0.2 w2_new:: 0.2 b_new: 0.18
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.38
# Actualizo pesos y bias
# w1_new: 0.2 w2_new:: 0.162 b_new: 0.142
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.34199999999999997
# Actualizo pesos y bias
# w1_new: 0.1658 w2_new:: 0.162 b_new: 0.10779999999999998
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.4356
# Actualizo pesos y bias
# w1_new: 0.22224 w2_new:: 0.21844000000000002 b_new: 0.16424
# Epocas: 1 SumaErrores: 0.30995567999999996
#
# --- Epoca: 2 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: 0.16424
# Actualizo pesos y bias
# w1_new: 0.22224 w2_new:: 0.21844000000000002 b_new: 0.147816
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.366256
# Actualizo pesos y bias
# w1_new: 0.22224 w2_new:: 0.18181440000000001 b_new: 0.1111904
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.3334304
# Actualizo pesos y bias
# w1_new: 0.18889696 w2_new:: 0.18181440000000001 b_new: 0.07784735999999999
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.44855872
# Actualizo pesos y bias
# w1_new: 0.244041088 w2_new:: 0.236958528 b_new: 0.132991488
# Epocas: 2 SumaErrores: 0.28819077603409915
#
# --- Epoca: 3 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: 0.132991488
# Actualizo pesos y bias
# w1_new: 0.244041088 w2_new:: 0.236958528 b_new: 0.1196923392
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3566508672
# Actualizo pesos y bias
# w1_new: 0.244041088 w2_new:: 0.20129344127999999 b_new: 0.08402725248
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.32806834048
# Actualizo pesos y bias
# w1_new: 0.211234253952 w2_new:: 0.20129344127999999 b_new: 0.051220418431999995
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.46374811366399993
# Actualizo pesos y bias
# w1_new: 0.2648594425856 w2_new:: 0.2549186299136 b_new: 0.1048456070656
# Epocas: 3 SumaErrores: 0.2700407492895929
#
# --- Epoca: 4 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: 0.1048456070656
# Actualizo pesos y bias
# w1_new: 0.2648594425856 w2_new:: 0.2549186299136 b_new: 0.09436104635904
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.34927967627264
# Actualizo pesos y bias
# w1_new: 0.2648594425856 w2_new:: 0.219990662286336 b_new: 0.059433078731775994
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.324292521317376
# Actualizo pesos y bias
# w1_new: 0.2324301904538624 w2_new:: 0.219990662286336 b_new: 0.02700382660003839
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.4794246793402368
# Actualizo pesos y bias
# w1_new: 0.2844877225198387 w2_new:: 0.2720481943523123 b_new: 0.07906135866601471
# Epocas: 4 SumaErrores: 0.2545765987202352
#
# --- Epoca: 5 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: 0.07906135866601471
# Actualizo pesos y bias
# w1_new: 0.2844877225198387 w2_new:: 0.2720481943523123 b_new: 0.07115522279941325
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.34320341715172553
# Actualizo pesos y bias
# w1_new: 0.2844877225198387 w2_new:: 0.23772785263713975 b_new: 0.03683488108424069
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.32132260360407944
# Actualizo pesos y bias
# w1_new: 0.2523554621594308 w2_new:: 0.23772785263713975 b_new: 0.004702620723832748
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.4947859355204033
# Actualizo pesos y bias
# w1_new: 0.30287686860739044 w2_new:: 0.2882492590850994 b_new: 0.05522402717179242
# Epocas: 5 SumaErrores: 0.24126437525681801
#
# --- Epoca: 6 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: 0.05522402717179242
# Actualizo pesos y bias
# w1_new: 0.30287686860739044 w2_new:: 0.2882492590850994 b_new: 0.04970162445461318
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3379508835397126
# Actualizo pesos y bias
# w1_new: 0.30287686860739044 w2_new:: 0.25445417073112814 b_new: 0.015906536100641917
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.31878340470803235
# Actualizo pesos y bias
# w1_new: 0.2709985281365872 w2_new:: 0.25445417073112814 b_new: -0.015971804370161317
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.509480894497554
# Actualizo pesos y bias
# w1_new: 0.3200504386868318 w2_new:: 0.30350608128137274 b_new: 0.03308010618008329
# Epocas: 6 SumaErrores: 0.22974617242125409
#
# --- Epoca: 7 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: 0.03308010618008329
# Actualizo pesos y bias
# w1_new: 0.3200504386868318 w2_new:: 0.30350608128137274 b_new: 0.029772095562074958
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3332781768434477
# Actualizo pesos y bias
# w1_new: 0.3200504386868318 w2_new:: 0.27017826359702796 b_new: -0.003555722122269813
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.316494716564562
# Actualizo pesos y bias
# w1_new: 0.2884009670303756 w2_new:: 0.27017826359702796 b_new: -0.03520519377872601
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.5233740368486776
# Actualizo pesos y bias
# w1_new: 0.33606356334550785 w2_new:: 0.3178408599121602 b_new: 0.012457402536406238
# Epocas: 7 SumaErrores: 0.2197549254740931
#
# --- Epoca: 8 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: 0.012457402536406238
# Actualizo pesos y bias
# w1_new: 0.33606356334550785 w2_new:: 0.3178408599121602 b_new: 0.011211662282765614
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3290525221949258
# Actualizo pesos y bias
# w1_new: 0.33606356334550785 w2_new:: 0.2849356076926676 b_new: -0.021693589936726966
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.31436997340878087
# Actualizo pesos y bias
# w1_new: 0.3046265660046298 w2_new:: 0.2849356076926676 b_new: -0.05313058727760506
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.5364315864196922
# Actualizo pesos y bias
# w1_new: 0.35098340736266054 w2_new:: 0.33129244905069843 b_new: -0.0067737459195742755
# Epocas: 8 SumaErrores: 0.21107745174559853
#
# --- Epoca: 9 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.0067737459195742755
# Actualizo pesos y bias
# w1_new: 0.35098340736266054 w2_new:: 0.33129244905069843 b_new: -0.006096371327616848
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.32519607772308157
# Actualizo pesos y bias
# w1_new: 0.35098340736266054 w2_new:: 0.29877284127839027 b_new: -0.03861597909992501
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.31236742826273556
# Actualizo pesos y bias
# w1_new: 0.319746664536387 w2_new:: 0.29877284127839027 b_new: -0.06985272192619857
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.5486667838885786
# Actualizo pesos y bias
# w1_new: 0.36487998614752915 w2_new:: 0.3439061628895324 b_new: -0.024719400315056428
# Epocas: 9 SumaErrores: 0.20353672740260687
#
# --- Epoca: 10 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.024719400315056428
# Actualizo pesos y bias
# w1_new: 0.36487998614752915 w2_new:: 0.3439061628895324 b_new: -0.022247460283550784
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3216587026059816
# Actualizo pesos y bias
# w1_new: 0.36487998614752915 w2_new:: 0.31174029262893427 b_new: -0.054413330544148944
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.3104666556033802
# Actualizo pesos y bias
# w1_new: 0.3338333205871911 w2_new:: 0.31174029262893427 b_new: -0.08545999610448697
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.5601136171116384
# Actualizo pesos y bias
# w1_new: 0.37782195887602726 w2_new:: 0.3557289309177704 b_new: -0.04147135781565081
# Epocas: 10 SumaErrores: 0.19698247190312673
#
# --- Epoca: 11 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.04147135781565081
# Actualizo pesos y bias
# w1_new: 0.37782195887602726 w2_new:: 0.3557289309177704 b_new: -0.03732422203408573
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.31840470888368466
# Actualizo pesos y bias
# w1_new: 0.37782195887602726 w2_new:: 0.32388846002940197 b_new: -0.0691646929224542
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.30865726595357307
# Actualizo pesos y bias
# w1_new: 0.34695623228066996 w2_new:: 0.32388846002940197 b_new: -0.1000304195178115
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.5708142727922605
# Actualizo pesos y bias
# w1_new: 0.3898748050014439 w2_new:: 0.3668070327501759 b_new: -0.05711184679703754
# Epocas: 11 SumaErrores: 0.19128556421157433
#
# --- Epoca: 12 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.05711184679703754
# Actualizo pesos y bias
# w1_new: 0.3898748050014439 w2_new:: 0.3668070327501759 b_new: -0.05140066211733379
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3154063706328421
# Actualizo pesos y bias
# w1_new: 0.3898748050014439 w2_new:: 0.3352663956868917 b_new: -0.082941299180618
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.3069335058208259
# Actualizo pesos y bias
# w1_new: 0.3591814544193613 w2_new:: 0.3352663956868917 b_new: -0.1136346497627006
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.5808132003435524
# Actualizo pesos y bias
# w1_new: 0.401100134385006 w2_new:: 0.37718507565253645 b_new: -0.07171596979705584
# Epocas: 12 SumaErrores: 0.18633434584101388
#
# --- Epoca: 13 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.07171596979705584
# Actualizo pesos y bias
# w1_new: 0.401100134385006 w2_new:: 0.37718507565253645 b_new: -0.06454437281735026
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3126407028351862
# Actualizo pesos y bias
# w1_new: 0.401100134385006 w2_new:: 0.3459210053690178 b_new: -0.09580844310086889
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.30529169128413713
# Actualizo pesos y bias
# w1_new: 0.37057096525659233 w2_new:: 0.3459210053690178 b_new: -0.1263376122292826
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.5901543583963275
# Actualizo pesos y bias
# w1_new: 0.4115555294169596 w2_new:: 0.3869055695293851 b_new: -0.08535304806891536
# Epocas: 13 SumaErrores: 0.18203192805093316
#
# --- Epoca: 14 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.08535304806891536
# Actualizo pesos y bias
# w1_new: 0.4115555294169596 w2_new:: 0.3869055695293851 b_new: -0.07681774326202383
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.31008782626736126
# Actualizo pesos y bias
# w1_new: 0.4115555294169596 w2_new:: 0.355896786902649 b_new: -0.10782652588875996
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.30372900352819965
# Actualizo pesos y bias
# w1_new: 0.38118262906413963 w2_new:: 0.355896786902649 b_new: -0.13819942624157994
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.5988799897252086
# Actualizo pesos y bias
# w1_new: 0.42129463009161877 w2_new:: 0.3960087879301281 b_new: -0.0980874252141008
# Epocas: 14 SumaErrores: 0.17829408652047682
#
# --- Epoca: 15 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.0980874252141008
# Actualizo pesos y bias
# w1_new: 0.42129463009161877 w2_new:: 0.3960087879301281 b_new: -0.08827868269269072
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3077301052374374
# Actualizo pesos y bias
# w1_new: 0.42129463009161877 w2_new:: 0.36523577740638435 b_new: -0.11905169321643447
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.30224293687518433
# Actualizo pesos y bias
# w1_new: 0.3910703364041003 w2_new:: 0.36523577740638435 b_new: -0.1492759869039529
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6070301269065318
# Actualizo pesos y bias
# w1_new: 0.43036732371344716 w2_new:: 0.4045327647157312 b_new: -0.10997899959460608
# Epocas: 15 SumaErrores: 0.17504753735230463
#
# --- Epoca: 16 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.10997899959460608
# Actualizo pesos y bias
# w1_new: 0.43036732371344716 w2_new:: 0.4045327647157312 b_new: -0.09898109963514547
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.30555166508058573
# Actualizo pesos y bias
# w1_new: 0.43036732371344716 w2_new:: 0.3739775982076726 b_new: -0.12953626614320404
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.3008310575702431
# Actualizo pesos y bias
# w1_new: 0.4002842179564228 w2_new:: 0.3739775982076726 b_new: -0.15961937190022835
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6146424442638672
# Actualizo pesos y bias
# w1_new: 0.4388199735300361 w2_new:: 0.4125133537812859 b_new: -0.12108361632661506
# Epocas: 16 SumaErrores: 0.1722284856735532
#
# --- Epoca: 17 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.12108361632661506
# Actualizo pesos y bias
# w1_new: 0.4388199735300361 w2_new:: 0.4125133537812859 b_new: -0.10897525469395355
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.3035380990873323
# Actualizo pesos y bias
# w1_new: 0.4388199735300361 w2_new:: 0.3821595438725527 b_new: -0.1393290646026868
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2994909089273493
# Actualizo pesos y bias
# w1_new: 0.40887088263730115 w2_new:: 0.3821595438725527 b_new: -0.16927815549542172
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6217522710144321
# Actualizo pesos y bias
# w1_new: 0.44669565553585794 w2_new:: 0.4199843167711095 b_new: -0.13145338259686493
# Epocas: 17 SumaErrores: 0.16978138437657578
#
# --- Epoca: 18 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.13145338259686493
# Actualizo pesos y bias
# w1_new: 0.44669565553585794 w2_new:: 0.4199843167711095 b_new: -0.11830804433717843
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.301676272433931
# Actualizo pesos y bias
# w1_new: 0.44669565553585794 w2_new:: 0.38981668952771636 b_new: -0.14847567158057154
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.29821998395528637
# Actualizo pesos y bias
# w1_new: 0.4168736571403293 w2_new:: 0.38981668952771636 b_new: -0.1782976699761002
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6283926766919455
# Actualizo pesos y bias
# w1_new: 0.4540343894711348 w2_new:: 0.42697742185852183 b_new: -0.14113693764529475
# Epocas: 18 SumaErrores: 0.16765786335612864
#
# --- Epoca: 19 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.14113693764529475
# Actualizo pesos y bias
# w1_new: 0.4540343894711348 w2_new:: 0.42697742185852183 b_new: -0.12702324388076527
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2999541779777566
# Actualizo pesos y bias
# w1_new: 0.4540343894711348 w2_new:: 0.3969820040607462 b_new: -0.15701866167854095
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.29701572779259383
# Actualizo pesos y bias
# w1_new: 0.4243328166918754 w2_new:: 0.3969820040607462 b_new: -0.18672023445780034
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6345945862948212
# Actualizo pesos y bias
# w1_new: 0.46087335806239327 w2_new:: 0.43352254543126406 b_new: -0.15017969308728246
# Epocas: 19 SumaErrores: 0.16581580148771025
#
# --- Epoca: 20 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.15017969308728246
# Actualizo pesos y bias
# w1_new: 0.46087335806239327 w2_new:: 0.43352254543126406 b_new: -0.1351617237785542
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.29836082165270983
# Actualizo pesos y bias
# w1_new: 0.46087335806239327 w2_new:: 0.40368646326599306 b_new: -0.16499780594382518
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2958755521185681
# Actualizo pesos y bias
# w1_new: 0.43128580285053647 w2_new:: 0.40368646326599306 b_new: -0.19458536115568198
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6403869049608475
# Actualizo pesos y bias
# w1_new: 0.4672471123544517 w2_new:: 0.4396477727699083 b_new: -0.15862405165176674
# Epocas: 20 SumaErrores: 0.16421852028908826
#
# --- Epoca: 21 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.15862405165176674
# Actualizo pesos y bias
# w1_new: 0.4672471123544517 w2_new:: 0.4396477727699083 b_new: -0.14276164648659007
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.29688612628331823
# Actualizo pesos y bias
# w1_new: 0.4672471123544517 w2_new:: 0.40995916014157646 b_new: -0.1724502591149219
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2947968532395298
# Actualizo pesos y bias
# w1_new: 0.43776742703049876 w2_new:: 0.40995916014157646 b_new: -0.20192994443887488
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6457966427332003
# Actualizo pesos y bias
# w1_new: 0.4731877627571787 w2_new:: 0.4453794958682564 b_new: -0.1665096087121949
# Epocas: 21 SumaErrores: 0.16283408236046892
#
# --- Epoca: 22 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.1665096087121949
# Actualizo pesos y bias
# w1_new: 0.4731877627571787 w2_new:: 0.4453794958682564 b_new: -0.1498586478409754
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.295520848027281
# Actualizo pesos y bias
# w1_new: 0.4731877627571787 w2_new:: 0.41582741106552834 b_new: -0.17941073264370352
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2937770301134752
# Actualizo pesos y bias
# w1_new: 0.4438100597458312 w2_new:: 0.41582741106552834 b_new: -0.20878843565505106
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6508490351563085
# Actualizo pesos y bias
# w1_new: 0.47872515623020034 w2_new:: 0.4507425075498975 b_new: -0.17387333917068193
# Epocas: 22 SumaErrores: 0.16163468054291297
#
# --- Epoca: 23 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.17387333917068193
# Actualizo pesos y bias
# w1_new: 0.47872515623020034 w2_new:: 0.4507425075498975 b_new: -0.15648600525361372
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.29425650229628375
# Actualizo pesos y bias
# w1_new: 0.47872515623020034 w2_new:: 0.4213168573202691 b_new: -0.1859116554832421
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2928135007469582
# Actualizo pesos y bias
# w1_new: 0.4494438061555045 w2_new:: 0.4213168573202691 b_new: -0.2151930055579379
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6555676579178358
# Actualizo pesos y bias
# w1_new: 0.48388704036372093 w2_new:: 0.4557600915284855 b_new: -0.18074977134972148
# Epocas: 23 SumaErrores: 0.16059610585494988
#
# --- Epoca: 24 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.18074977134972148
# Actualizo pesos y bias
# w1_new: 0.48388704036372093 w2_new:: 0.4557600915284855 b_new: -0.16267479421474934
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.29308529731373617
# Actualizo pesos y bias
# w1_new: 0.48388704036372093 w2_new:: 0.4264515617971119 b_new: -0.19198332394612297
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.29190371641759794
# Actualizo pesos y bias
# w1_new: 0.45469666872196113 w2_new:: 0.4264515617971119 b_new: -0.22117369558788277
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6599745349311902
# Actualizo pesos y bias
# w1_new: 0.48869921522884213 w2_new:: 0.4604541083039929 b_new: -0.1871711490810018
# Epocas: 24 SumaErrores: 0.15969728394906177
#
# --- Epoca: 25 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.1871711490810018
# Actualizo pesos y bias
# w1_new: 0.48869921522884213 w2_new:: 0.4604541083039929 b_new: -0.1684540341729016
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2920000741310913
# Actualizo pesos y bias
# w1_new: 0.48869921522884213 w2_new:: 0.4312541008908838 b_new: -0.19765404158601074
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2910451736428314
# Actualizo pesos y bias
# w1_new: 0.459594697864559 w2_new:: 0.4312541008908838 b_new: -0.2267585589502939
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6640902398051489
# Actualizo pesos y bias
# w1_new: 0.4931856738840441 w2_new:: 0.4648450769103689 b_new: -0.1931675829308088
# Epocas: 25 SumaErrores: 0.15891987121790682
#
# --- Epoca: 26 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.1931675829308088
# Actualizo pesos y bias
# w1_new: 0.4931856738840441 w2_new:: 0.4648450769103689 b_new: -0.1738508246377279
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.290994252272641
# Actualizo pesos y bias
# w1_new: 0.4931856738840441 w2_new:: 0.4357456516831048 b_new: -0.20295024986499202
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2902354240190521
# Actualizo pesos y bias
# w1_new: 0.4641621314821389 w2_new:: 0.4357456516831048 b_new: -0.23197379226689724
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6679339908983466
# Actualizo pesos y bias
# w1_new: 0.4973687323923043 w2_new:: 0.46895225259327017 b_new: -0.1987671913567319
# Epocas: 26 SumaErrores: 0.15824790285363133
#
# --- Epoca: 27 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.1987671913567319
# Actualizo pesos y bias
# w1_new: 0.4973687323923043 w2_new:: 0.46895225259327017 b_new: -0.17889047222105872
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2900617803722114
# Actualizo pesos y bias
# w1_new: 0.4973687323923043 w2_new:: 0.439946074556049 b_new: -0.20789665025827986
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2894720821340244
# Actualizo pesos y bias
# w1_new: 0.4684215241789018 w2_new:: 0.439946074556049 b_new: -0.2368438584716823
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6715237402632686
# Actualizo pesos y bias
# w1_new: 0.501269150152575 w2_new:: 0.47279370052972214 b_new: -0.20399623249800913
# Epocas: 27 SumaErrores: 0.15766748616909038
#
# --- Epoca: 28 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.20399623249800913
# Actualizo pesos y bias
# w1_new: 0.501269150152575 w2_new:: 0.47279370052972214 b_new: -0.18359660924820823
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28919709128151394
# Actualizo pesos y bias
# w1_new: 0.501269150152575 w2_new:: 0.44387399140157074 b_new: -0.21251631837635962
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28875283177621536
# Actualizo pesos y bias
# w1_new: 0.47239386697495345 w2_new:: 0.44387399140157074 b_new: -0.24139160155398115
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.674876256822543
# Actualizo pesos y bias
# w1_new: 0.5049062412926991 w2_new:: 0.4763863657193164 b_new: -0.20887922723623545
# Epocas: 28 SumaErrores: 0.1571665333577872
#
# --- Epoca: 29 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.20887922723623545
# Actualizo pesos y bias
# w1_new: 0.5049062412926991 w2_new:: 0.4763863657193164 b_new: -0.1879913045126119
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28839506120670455
# Actualizo pesos y bias
# w1_new: 0.5049062412926991 w2_new:: 0.447546859598646 b_new: -0.21683081063328236
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28807543065941676
# Actualizo pesos y bias
# w1_new: 0.47609869822675743 w2_new:: 0.447546859598646 b_new: -0.24563835369922404
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6780072041261794
# Actualizo pesos y bias
# w1_new: 0.5082979778141394 w2_new:: 0.47974613918602804 b_new: -0.213439074111842
# Epocas: 29 SumaErrores: 0.15673452862173703
#
# --- Epoca: 30 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.213439074111842
# Actualizo pesos y bias
# w1_new: 0.5082979778141394 w2_new:: 0.47974613918602804 b_new: -0.1920951667006578
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28765097248537025
# Actualizo pesos y bias
# w1_new: 0.5082979778141394 w2_new:: 0.450981041937491 b_new: -0.22086026394919483
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2874377138649446
# Actualizo pesos y bias
# w1_new: 0.47955420642764496 w2_new:: 0.450981041937491 b_new: -0.2496040353356893
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6809312130294466
# Actualizo pesos y bias
# w1_new: 0.5114610851247003 w2_new:: 0.48288792063454633 b_new: -0.21769715663863398
# Epocas: 30 SumaErrores: 0.15636232525013288
#
# --- Epoca: 31 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.21769715663863398
# Actualizo pesos y bias
# w1_new: 0.5114610851247003 w2_new:: 0.48288792063454633 b_new: -0.19592744097477058
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2869604796597758
# Actualizo pesos y bias
# w1_new: 0.5114610851247003 w2_new:: 0.45419187266856875 b_new: -0.22462348894074816
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2868375961839522
# Actualizo pesos y bias
# w1_new: 0.48277732550630514 w2_new:: 0.45419187266856875 b_new: -0.2533072485591434
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6836619496157306
# Actualizo pesos y bias
# w1_new: 0.5144111305447321 w2_new:: 0.4858256777069957 b_new: -0.22167344352071644
# Epocas: 31 SumaErrores: 0.15604196880031157
#
# --- Epoca: 32 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.22167344352071644
# Actualizo pesos y bias
# w1_new: 0.5144111305447321 w2_new:: 0.4858256777069957 b_new: -0.19950609916864478
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2863195785383509
# Actualizo pesos y bias
# w1_new: 0.5144111305447321 w2_new:: 0.4571937198531606 b_new: -0.22813805702247988
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2862730735222522
# Actualizo pesos y bias
# w1_new: 0.48578382319250685 w2_new:: 0.4571937198531606 b_new: -0.2567653643747051
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6862121786709624
# Actualizo pesos y bias
# w1_new: 0.5171626053254106 w2_new:: 0.48857250198606433 b_new: -0.22538658224180133
# Epocas: 32 SumaErrores: 0.15576654302750598
#
# --- Epoca: 33 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.22538658224180133
# Actualizo pesos y bias
# w1_new: 0.5171626053254106 w2_new:: 0.48857250198606433 b_new: -0.2028479240176212
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28572457796844314
# Actualizo pesos y bias
# w1_new: 0.5171626053254106 w2_new:: 0.46000004418922 b_new: -0.2314203818144655
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2857422235109451
# Actualizo pesos y bias
# w1_new: 0.48858838297431606 w2_new:: 0.46000004418922 b_new: -0.25999460416556003
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.688593822997976
# Actualizo pesos y bias
# w1_new: 0.5197290006745184 w2_new:: 0.4911406618894224 b_new: -0.22885398646535762
# Epocas: 33 SumaErrores: 0.15553003564094
#
# --- Epoca: 34 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.22885398646535762
# Actualizo pesos y bias
# w1_new: 0.5197290006745184 w2_new:: 0.4911406618894224 b_new: -0.20596858781882185
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2851720740706005
# Actualizo pesos y bias
# w1_new: 0.5197290006745184 w2_new:: 0.46262345448236236 b_new: -0.23448579522588192
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2852432054486365
# Actualizo pesos y bias
# w1_new: 0.4912046801296548 w2_new:: 0.46262345448236236 b_new: -0.26301011577074557
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6908180188412716
# Actualizo pesos y bias
# w1_new: 0.5221228782455276 w2_new:: 0.4935416525982352 b_new: -0.23209191765487272
# Epocas: 34 SumaErrores: 0.15532722133933177
#
# --- Epoca: 35 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.23209191765487272
# Actualizo pesos y bias
# w1_new: 0.5221228782455276 w2_new:: 0.4935416525982352 b_new: -0.20888272588938545
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28465892670884974
# Actualizo pesos y bias
# w1_new: 0.5221228782455276 w2_new:: 0.46507575992735023 b_new: -0.23734861856027042
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28477425968525716
# Actualizo pesos y bias
# w1_new: 0.4936454522770019 w2_new:: 0.46507575992735023 b_new: -0.26582604452879616
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6928951676755559
# Actualizo pesos y bias
# w1_new: 0.5243559355094463 w2_new:: 0.49578624315979464 b_new: -0.23511556129635175
# Epocas: 35 SumaErrores: 0.15515355990603086
#
# --- Epoca: 36 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.23511556129635175
# Actualizo pesos y bias
# w1_new: 0.5243559355094463 w2_new:: 0.49578624315979464 b_new: -0.21160400516671657
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28418223799307807
# Actualizo pesos y bias
# w1_new: 0.5243559355094463 w2_new:: 0.46736801936048683 b_new: -0.24002222896602438
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2843337065434219
# Actualizo pesos y bias
# w1_new: 0.49592256485510405 w2_new:: 0.46736801936048683 b_new: -0.2684555996203666
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6948349845952243
# Actualizo pesos y bias
# w1_new: 0.5264390663955816 w2_new:: 0.4978845209009644 b_new: -0.237939098079889
# Epocas: 36 SumaErrores: 0.15500510742908535
#
# --- Epoca: 37 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.237939098079889
# Actualizo pesos y bias
# w1_new: 0.5264390663955816 w2_new:: 0.4978845209009644 b_new: -0.2141451882719001
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2837393326290643
# Actualizo pesos y bias
# w1_new: 0.5264390663955816 w2_new:: 0.469510587638058 b_new: -0.24251912153480654
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28391994486077504
# Actualizo pesos y bias
# w1_new: 0.4980470719095041 w2_new:: 0.469510587638058 b_new: -0.270911116020884
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6966465435266781
# Actualizo pesos y bias
# w1_new: 0.5283824175568362 w2_new:: 0.4998459332853902 b_new: -0.24057577037355182
# Epocas: 37 SumaErrores: 0.15487843895995748
#
# --- Epoca: 38 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.24057577037355182
# Actualizo pesos y bias
# w1_new: 0.5283824175568362 w2_new:: 0.4998459332853902 b_new: -0.21651819333619665
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2833277399491935
# Actualizo pesos y bias
# w1_new: 0.5283824175568362 w2_new:: 0.47151315929047083 b_new: -0.244850967331116
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28353145022572024
# Actualizo pesos y bias
# w1_new: 0.5000292725342642 w2_new:: 0.47151315929047083 b_new: -0.273204112353688
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.698338319471047
# Actualizo pesos y bias
# w1_new: 0.5301954405871595 w2_new:: 0.5016793273433662 b_new: -0.24303794430079273
# Epocas: 38 SumaErrores: 0.15477058114109898
#
# --- Epoca: 39 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.24303794430079273
# Actualizo pesos y bias
# w1_new: 0.5301954405871595 w2_new:: 0.5016793273433662 b_new: -0.21873414987071346
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2829451774726527
# Actualizo pesos y bias
# w1_new: 0.5301954405871595 w2_new:: 0.4733848095961009 b_new: -0.24702866761797873
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2831667729691808
# Actualizo pesos y bias
# w1_new: 0.5018787632902414 w2_new:: 0.4733848095961009 b_new: -0.2753453449148968
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.6999182279714455
# Actualizo pesos y bias
# w1_new: 0.5318869404930968 w2_new:: 0.5033929867989564 b_new: -0.24533716771204137
# Epocas: 39 SumaErrores: 0.15467895352128153
#
# --- Epoca: 40 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.24533716771204137
# Actualizo pesos y bias
# w1_new: 0.5318869404930968 w2_new:: 0.5033929867989564 b_new: -0.22080345094083723
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2825895358581192
# Actualizo pesos y bias
# w1_new: 0.5318869404930968 w2_new:: 0.47513403321314446 b_new: -0.24906240452664916
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28282453596644763
# Actualizo pesos y bias
# w1_new: 0.5036044868964521 w2_new:: 0.47513403321314446 b_new: -0.2773448581232939
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7013936619863027
# Actualizo pesos y bias
# w1_new: 0.5334651206978218 w2_new:: 0.5049946670145142 b_new: -0.24748422432192418
# Epocas: 40 SumaErrores: 0.1546013174420302
#
# --- Epoca: 41 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.24748422432192418
# Actualizo pesos y bias
# w1_new: 0.5334651206978218 w2_new:: 0.5049946670145142 b_new: -0.22273580188973177
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2822588651247825
# Actualizo pesos y bias
# w1_new: 0.5334651206978218 w2_new:: 0.47676878050203597 b_new: -0.25096168840221
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2825034322956118
# Actualizo pesos y bias
# w1_new: 0.5052147774682606 w2_new:: 0.47676878050203597 b_new: -0.27921203163177116
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7027715263385255
# Actualizo pesos y bias
# w1_new: 0.5349376248344081 w2_new:: 0.5064916278681835 b_new: -0.24948918426562372
# Epocas: 41 SumaErrores: 0.15453573152184294
#
# --- Epoca: 42 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.24948918426562372
# Actualizo pesos y bias
# w1_new: 0.5349376248344081 w2_new:: 0.5064916278681835 b_new: -0.22454026583906134
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28195136202912213
# Actualizo pesos y bias
# w1_new: 0.5349376248344081 w2_new:: 0.4782964916652713 b_new: -0.25273540204197353
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28220222279243456
# Actualizo pesos y bias
# w1_new: 0.5067174025551646 w2_new:: 0.4782964916652713 b_new: -0.280955624321217
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7040582698992188
# Actualizo pesos y bias
# w1_new: 0.5363115755652428 w2_new:: 0.5078906646753494 b_new: -0.2513614513111389
# Epocas: 42 SumaErrores: 0.15448051288981896
#
# --- Epoca: 43 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.2513614513111389
# Actualizo pesos y bias
# w1_new: 0.5363115755652428 w2_new:: 0.5078906646753494 b_new: -0.226225306180025
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28166535849532437
# Actualizo pesos y bias
# w1_new: 0.5363115755652428 w2_new:: 0.47972412882581694 b_new: -0.25439184202955745
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28191973353568534
# Actualizo pesos y bias
# w1_new: 0.5081196022116743 w2_new:: 0.47972412882581694 b_new: -0.282583815383126
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7052599156543653
# Actualizo pesos y bias
# w1_new: 0.5375936106462378 w2_new:: 0.5091981372603804 b_new: -0.2531098069485625
# Epocas: 43 SumaErrores: 0.15443420342922268
#
# --- Epoca: 44 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.2531098069485625
# Actualizo pesos y bias
# w1_new: 0.5375936106462378 w2_new:: 0.5091981372603804 b_new: -0.22779882625370623
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2813993110066742
# Actualizo pesos y bias
# w1_new: 0.5375936106462378 w2_new:: 0.481058206159713 b_new: -0.25593875735437366
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2816548532918641
# Actualizo pesos y bias
# w1_new: 0.5094281253170514 w2_new:: 0.481058206159713 b_new: -0.28410424268356005
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7063820887932044
# Actualizo pesos y bias
# w1_new: 0.538789916437731 w2_new:: 0.5104199972803926 b_new: -0.2547424515628805
# Epocas: 44 SumaErrores: 0.15439554038643638
#
# --- Epoca: 45 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.2547424515628805
# Actualizo pesos y bias
# w1_new: 0.538789916437731 w2_new:: 0.5104199972803926 b_new: -0.22926820640659246
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2811517908738001
# Actualizo pesos y bias
# w1_new: 0.538789916437731 w2_new:: 0.4823048181930125 b_new: -0.25738338549397244
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28140653094375856
# Actualizo pesos y bias
# w1_new: 0.5106492633433551 w2_new:: 0.4823048181930125 b_new: -0.2855240385883483
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7074300429480194
# Actualizo pesos y bias
# w1_new: 0.5399062590485532 w2_new:: 0.5115618138982105 b_new: -0.2562670428831502
# Epocas: 45 SumaErrores: 0.15436343078350495
#
# --- Epoca: 46 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.2562670428831502
# Actualizo pesos y bias
# w1_new: 0.5399062590485532 w2_new:: 0.5115618138982105 b_new: -0.23064033859483518
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28092147530337536
# Actualizo pesos y bias
# w1_new: 0.5399062590485532 w2_new:: 0.48346966636787303 b_new: -0.25873248612517274
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.2811737729233804
# Actualizo pesos y bias
# w1_new: 0.5117888817562151 w2_new:: 0.48346966636787303 b_new: -0.2868498634175108
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7084086847065774
# Actualizo pesos y bias
# w1_new: 0.5409480132855573 w2_new:: 0.5126287978972153 b_new: -0.25769073188816854
# Epocas: 46 SumaErrores: 0.15433692914460811
#
# --- Epoca: 47 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.25769073188816854
# Actualizo pesos y bias
# w1_new: 0.5409480132855573 w2_new:: 0.5126287978972153 b_new: -0.2319216586993517
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2807071391978636
# Actualizo pesos y bias
# w1_new: 0.5409480132855573 w2_new:: 0.4845580839774289 b_new: -0.25999237261913805
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28095564066641926
# Actualizo pesos y bias
# w1_new: 0.5128524492189154 w2_new:: 0.4845580839774289 b_new: -0.28808793668578
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7093225965105643
# Actualizo pesos y bias
# w1_new: 0.5419201895678589 w2_new:: 0.5136258243263725 b_new: -0.25902019633683643
# Epocas: 47 SumaErrores: 0.15431521810967352
#
# --- Epoca: 48 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.25902019633683643
# Actualizo pesos y bias
# w1_new: 0.5419201895678589 w2_new:: 0.5136258243263725 b_new: -0.23311817670315277
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2805076476232197
# Actualizo pesos y bias
# w1_new: 0.5419201895678589 w2_new:: 0.4855750595640505 b_new: -0.26116894146547476
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28075124810238417
# Actualizo pesos y bias
# w1_new: 0.5138450647576205 w2_new:: 0.4855750595640505 b_new: -0.2892440662757132
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7101760580459577
# Actualizo pesos y bias
# w1_new: 0.5428274589530248 w2_new:: 0.5145574537594547 b_new: -0.260261672080309
# Epocas: 48 SumaErrores: 0.15429759156315612
#
# --- Epoca: 49 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.260261672080309
# Actualizo pesos y bias
# w1_new: 0.5428274589530248 w2_new:: 0.5145574537594547 b_new: -0.23423550487227807
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.28032194888717665
# Actualizo pesos y bias
# w1_new: 0.5428274589530248 w2_new:: 0.48652525887073705 b_new: -0.26226769976099573
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.280559759192029
# Actualizo pesos y bias
# w1_new: 0.5147714830338218 w2_new:: 0.48652525887073705 b_new: -0.2903236756801986
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7109730662243603
# Actualizo pesos y bias
# w1_new: 0.5436741764113858 w2_new:: 0.5154279522483011 b_new: -0.26142098230263466
# Epocas: 49 SumaErrores: 0.15428343995379026
#
# --- Epoca: 50 ---
# Iteracion: 1
# num1: 0 num2: 0
# Y: -0.26142098230263466
# Actualizo pesos y bias
# w1_new: 0.5436741764113858 w2_new:: 0.5154279522483011 b_new: -0.23527888407237119
# Iteracion: 2
# num1: 0 num2: 1
# Y: 0.2801490681759299
# Actualizo pesos y bias
# w1_new: 0.5436741764113858 w2_new:: 0.48741304543070807 b_new: -0.2632937908899642
# Iteracion: 3
# num1: 1 num2: 0
# Y: 0.28038038552142164
# Actualizo pesos y bias
# w1_new: 0.5156361378592437 w2_new:: 0.48741304543070807 b_new: -0.29133182944210634
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.7117173538478454
# Actualizo pesos y bias
# w1_new: 0.5444644024744592 w2_new:: 0.5162413100459236 b_new: -0.26250356482689086
# Epocas: 50 SumaErrores: 0.15427223752277283

# %%
# Crear la gráfica de el error cuadrático medio por epoca
epocas = range(1, len(error) + 1)
plt.plot(epocas, error, marker='o', linestyle='-', color='b')  # Línea con puntos marcados
plt.title('Error cuadrático medio (LMS) por Época')  # Título de la gráfica
plt.xlabel('Época')  # Etiqueta del eje X
plt.ylabel('Error cuadrático medio')  # Etiqueta del eje Y
plt.grid(True)  # Agregar una cuadrícula para mejor visualización
plt.xticks(epocas)  # Asegurar que las épocas se muestren correctamente en el eje X
plt.show()  # Mostrar la gráfica

# %%
def validar_entrada(mensaje):
    while True:
        try:
            valor = float(input(mensaje))
            if -1 <= valor <= 1:
                return valor
            else:
                print("Error: El valor debe estar entre -1 y 1. Intente nuevamente.")
        except ValueError:
            print("Error: Ingrese un número válido.")

# Datos de ejemplo (simulando tus datos)
# atributos     ->   [x1, x2]
individuo = np.array([[0, 0], 
                      [0, 1],  
                      [1, 0], 
                      [1, 1],
                     ])
# 1 : true    0 : false
clases = np.array([0, 0, 0, 1])
# Crear la figura
plt.figure(figsize=(6, 5), dpi=200)
plt.title("Adaline con su recta de clasificacion", fontsize=15)

# Graficar los puntos de entrada
plt.scatter(individuo[clases == 0].T[0], 
            individuo[clases == 0].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="False")
plt.scatter(individuo[clases == 1].T[0],
            individuo[clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")

# Generar y graficar la región de decisión
for x1 in np.arange(-1, 1.05, 0.05):
    for x2 in np.arange(-1, 1.05, 0.05):
        # Calcular el valor de y
        y = (w1 * x1) + (w2 * x2) + b
        
        # Función de activación
        if y >= 0:
            color = "blue"  # Clase 1
        else:
            color = "red"   # Clase 0
        
        # Graficar el punto
        plt.scatter(x1, x2, marker="s", s=110,
                    color=color, alpha=0.2, linewidths=0)

# Calcular puntos para la recta (usando la ecuación w1*x1 + w2*x2 + b = 0)
x1_vals = np.array([-1.5, 1.5])  # Rango amplio para graficar
x2_vals = (-w1 * x1_vals - b) / w2  # Despejamos x2 de la ecuación

# Graficar la recta de decisión
plt.plot(x1_vals, x2_vals, color="green", linestyle="--", linewidth=2, label="Recta clasificadora")

# Solicitar valores de x1 y x2 al usuario
x1 = validar_entrada("Ingrese x1 con un valor entre -1 y 1: ")
x2 = validar_entrada("Ingrese x2 con un valor entre -1 y 1: ")

# Determinar la clase del punto ingresado
y = (w1 * x1) + (w2 * x2) + b
if y >= 0:
    color = "blue"  # Clase 1
else:
    color = "red"   # Clase -1

# Graficar el punto ingresado
plt.scatter(x1, x2, marker="*", s=200, color=color, label="Punto ingresado")

# Configuraciones adicionales del gráfico
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.show()
# Out:
# Ingrese x1 con un valor entre -1 y 1:  0.6
# Ingrese x2 con un valor entre -1 y 1:  0.6
