# %%
# Este codigo solo muestra los puntos clasifiacados segun su clase
import numpy as np
import matplotlib.pyplot as plt

# atributos     ->   [x1, x2]
individuo = np.array([[1, 1], 
                      [1,-1],  
                      [-1,1], 
                      [-1,-1],
                     ])
# 1 : true    -1 : false
clases = np.array([-1, 1, -1, -1])

# Gráfica de dispersión (x1, x2)
plt.figure(figsize=(7, 7))
plt.title("Data SET", fontsize=20)
plt.scatter(individuo [clases == -1].T[0], 
            individuo [clases == -1].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="false")
plt.scatter(individuo [clases == 1].T[0],
            individuo [clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.grid()
plt.show()

# %%
# Este codigo ejecuta las epocas definidas en el while.

# pesos    se pueden cambiar
w1 = 0.2
w2 = 0.2
# bias   se puede cambiar
b = 0.2
# α parámetro de aprendizaje  se puede cambiar
pa = 0.2
numEpocas=17 # **aqui se cambia el numero de epocas**
# épocas 
epocas = 0
# guarda la suma de los errores por iteracion y vuelve a 0 al incio de cada epoca
sumaErrores=0
# se guarda el error por epoca
error= []
# contaSinError = 0
longitud = len(clases)
# guarda los aciertos de cada epoca
# aciertos = []
while epocas != numEpocas:   
    print("\n--- Epoca:", epocas+1, "---")
    for i in range(individuo.shape[0]):
        print("Iteracion:", i + 1)  # Imprimir el índice de la fila
        print("num1:", individuo[i, 0], "num2:", individuo[i, 1])
        y = (w1 * individuo[i, 0]) + (w2 * individuo[i, 1]) + b
        print("Y:", y)

        # Verificar si la predicción es correcta
        if y == clases[i]:
            print("No actualizo pesos, ni bias")
            #contaSinError += 1
        else:
            print("Actualizo pesos y bias")
            w1 = w1 + pa * (clases[i]-y) * individuo[i, 0]
            w2 = w2 + pa * (clases[i]-y) * individuo[i, 1]
            b = b + pa * (clases[i]-y)
            print("w1_new:", w1, "w2_new::", w2, "b_new:", b)
            # calculo el error en la iteracion correpondiente
            sumaErrores=(((clases[i]-y) ** 2) /2)+sumaErrores
    # Incrementar épocas después de recorrer todos los individuos
    epocas += 1
    print("Epocas:", epocas, "SumaErrores:", sumaErrores)
    error.append(sumaErrores)
    sumaErrores = 0
# Out:
# --- Epoca: 1 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: 0.6000000000000001
# Actualizo pesos y bias
# w1_new: -0.12000000000000005 w2_new:: -0.12000000000000005 b_new: -0.12000000000000005
# Iteracion: 2
# num1: 1 num2: -1
# Y: -0.12000000000000005
# Actualizo pesos y bias
# w1_new: 0.10399999999999998 w2_new:: -0.3440000000000001 b_new: 0.10399999999999998
# Iteracion: 3
# num1: -1 num2: 1
# Y: -0.3440000000000001
# Actualizo pesos y bias
# w1_new: 0.23519999999999996 w2_new:: -0.47520000000000007 b_new: -0.027200000000000002
# Iteracion: 4
# num1: -1 num2: -1
# Y: 0.2128000000000001
# Actualizo pesos y bias
# w1_new: 0.47775999999999996 w2_new:: -0.23264000000000004 b_new: -0.26976
# Epocas: 1 SumaErrores: 2.8578099200000002
#
# --- Epoca: 2 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.02464000000000008
# Actualizo pesos y bias
# w1_new: 0.28268799999999994 w2_new:: -0.42771200000000004 b_new: -0.464832
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2455679999999999
# Actualizo pesos y bias
# w1_new: 0.43357439999999997 w2_new:: -0.5785984000000001 b_new: -0.3139456
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.3261184000000001
# Actualizo pesos y bias
# w1_new: 0.3683507199999999 w2_new:: -0.5133747200000001 b_new: -0.24872191999999996
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.1036979199999998
# Actualizo pesos y bias
# w1_new: 0.547611136 w2_new:: -0.334114304 b_new: -0.427982336
# Epocas: 2 SumaErrores: 1.2151027008274433
#
# --- Epoca: 3 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.214485504
# Actualizo pesos y bias
# w1_new: 0.3905082368 w2_new:: -0.49121720319999995 b_new: -0.5850852352
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2966402048
# Actualizo pesos y bias
# w1_new: 0.53118019584 w2_new:: -0.63188916224 b_new: -0.44441327616
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.60748263424
# Actualizo pesos y bias
# w1_new: 0.409683668992 w2_new:: -0.5103926353920001 b_new: -0.322916749312
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.22220778291199988
# Actualizo pesos y bias
# w1_new: 0.5652421124096 w2_new:: -0.3548341919744 b_new: -0.47847519272960004
# Epocas: 3 SumaErrores: 1.042871954397878
#
# --- Epoca: 4 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.2680672722944001
# Actualizo pesos y bias
# w1_new: 0.41885556686848 w2_new:: -0.50122073751552 b_new: -0.62486173827072
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.29521456611328
# Actualizo pesos y bias
# w1_new: 0.559812653645824 w2_new:: -0.642177824292864 b_new: -0.483904651493376
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.685895129432064
# Actualizo pesos y bias
# w1_new: 0.42263362775941116 w2_new:: -0.5049987984064511 b_new: -0.3467256256069632
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.2643604549599232
# Actualizo pesos y bias
# w1_new: 0.5697615367674265 w2_new:: -0.35787088939843575 b_new: -0.49385353461497855
# Epocas: 4 SumaErrores: 1.0220328472554256
#
# --- Epoca: 5 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.28196288724598784
# Actualizo pesos y bias
# w1_new: 0.426154114216624 w2_new:: -0.5014783119492382 b_new: -0.637460957165781
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2901714690000812
# Actualizo pesos y bias
# w1_new: 0.5681198204166078 w2_new:: -0.643444018149222 b_new: -0.4954952509657972
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.707059089531627
# Actualizo pesos y bias
# w1_new: 0.4267080025102824 w2_new:: -0.5020322002428966 b_new: -0.35408343305947176
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.27875923532685754
# Actualizo pesos y bias
# w1_new: 0.570956155444911 w2_new:: -0.3577840473082681 b_new: -0.49833158599410027
# Epocas: 5 SumaErrores: 1.0197773177146068
#
# --- Epoca: 6 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.28515947785745743
# Actualizo pesos y bias
# w1_new: 0.42798805101640247 w2_new:: -0.5007521517367767 b_new: -0.6412996904226088
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.28744051233057033
# Actualizo pesos y bias
# w1_new: 0.5704999485502884 w2_new:: -0.6432640492706626 b_new: -0.4987877928887229
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.7125517907096737
# Actualizo pesos y bias
# w1_new: 0.42798959040835366 w2_new:: -0.5007536911287278 b_new: -0.35627743474678814
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.283513334026414
# Actualizo pesos y bias
# w1_new: 0.5712869236030709 w2_new:: -0.3574563579340106 b_new: -0.49957476794150535
# Epocas: 6 SumaErrores: 1.0199105962631252
#
# --- Epoca: 7 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.28574420227244507
# Actualizo pesos y bias
# w1_new: 0.4284357640575599 w2_new:: -0.5003075174795216 b_new: -0.6424259274870163
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2863173540500652
# Actualizo pesos y bias
# w1_new: 0.5711722932475469 w2_new:: -0.6430440466695087 b_new: -0.49968939829702935
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.713905738214085
# Actualizo pesos y bias
# w1_new: 0.4283911456047299 w2_new:: -0.5002628990266916 b_new: -0.3569082506542124
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.28503649723225066
# Actualizo pesos y bias
# w1_new: 0.5713838461582798 w2_new:: -0.3572701984731418 b_new: -0.49990095120776223
# Epocas: 7 SumaErrores: 1.0201692385312267
#
# --- Epoca: 8 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.28578730352262427
# Actualizo pesos y bias
# w1_new: 0.42854130686280456 w2_new:: -0.500112737768617 b_new: -0.6427434905032374
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2859105541281841
# Actualizo pesos y bias
# w1_new: 0.5713591960371678 w2_new:: -0.6429306269429802 b_new: -0.4999256013288742
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.7142154243090222
# Actualizo pesos y bias
# w1_new: 0.42851611117536337 w2_new:: -0.5000875420811758 b_new: -0.3570825164670698
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.28551108556125737
# Actualizo pesos y bias
# w1_new: 0.5714138940631119 w2_new:: -0.3571897591934272 b_new: -0.49998029935481836
# Epocas: 8 SumaErrores: 1.0203107968458853
#
# --- Epoca: 9 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.28575616448513363
# Actualizo pesos y bias
# w1_new: 0.42856512696013865 w2_new:: -0.5000385262964004 b_new: -0.6428290664577916
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.28577458679874757
# Actualizo pesos y bias
# w1_new: 0.5714102096003891 w2_new:: -0.642883608936651 b_new: -0.49998398381754106
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.714277802354581
# Actualizo pesos y bias
# w1_new: 0.42855464912947294 w2_new:: -0.5000280484657348 b_new: -0.35712842334662487
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.285655024010363
# Actualizo pesos y bias
# w1_new: 0.5714236443274003 w2_new:: -0.3571590532678074 b_new: -0.49999741854455226
# Epocas: 9 SumaErrores: 1.020371860545806
#
# --- Epoca: 10 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.2857328274849593
# Actualizo pesos y bias
# w1_new: 0.4285702098243922 w2_new:: -0.5000124877708155 b_new: -0.6428508530475604
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.28573184454764733
# Actualizo pesos y bias
# w1_new: 0.5714238409148628 w2_new:: -0.6428661188612861 b_new: -0.49999722195708984
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.7142871817332386
# Actualizo pesos y bias
# w1_new: 0.42856640456821504 w2_new:: -0.5000086825146384 b_new: -0.35713978561044213
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.2856975076640188
# Actualizo pesos y bias
# w1_new: 0.5714269030354113 w2_new:: -0.3571481840474421 b_new: -0.5000002840776384
# Epocas: 10 SumaErrores: 1.020395410085872
#
# --- Epoca: 11 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.28572156508966917
# Actualizo pesos y bias
# w1_new: 0.42857121605334514 w2_new:: -0.5000038710295083 b_new: -0.6428559710597046
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2857191160231488
# Actualizo pesos y bias
# w1_new: 0.5714273928487154 w2_new:: -0.6428600478248785 b_new: -0.4999997942643344
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.7142872349379281
# Actualizo pesos y bias
# w1_new: 0.42856994586112973 w2_new:: -0.5000026008372929 b_new: -0.35714234727674876
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.2857096923005856
# Actualizo pesos y bias
# w1_new: 0.5714280074010126 w2_new:: -0.35714453929740997 b_new: -0.5000004088166317
# Epocas: 11 SumaErrores: 1.0204038807306492
#
# --- Epoca: 12 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.285716940713029
# Actualizo pesos y bias
# w1_new: 0.42857139554361845 w2_new:: -0.5000011511548041 b_new: -0.6428570206740258
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.28571552602439676
# Actualizo pesos y bias
# w1_new: 0.5714282903387391 w2_new:: -0.6428580459499248 b_new: -0.5000001258789052
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.714286462167569
# Actualizo pesos y bias
# w1_new: 0.42857099790522524 w2_new:: -0.5000007535164109 b_new: -0.35714283344539133
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.28571307783420563
# Actualizo pesos y bias
# w1_new: 0.5714283823383841 w2_new:: -0.35714336908325206 b_new: -0.5000002178785502
# Epocas: 12 SumaErrores: 1.0204067778799524
#
# --- Epoca: 13 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.28571520462341815
# Actualizo pesos y bias
# w1_new: 0.42857142326306774 w2_new:: -0.5000003281585684 b_new: -0.6428571769538666
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2857145744677696
# Actualizo pesos y bias
# w1_new: 0.5714285083695139 w2_new:: -0.6428574132650146 b_new: -0.5000000918474204
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.7142860134819489
# Actualizo pesos y bias
# w1_new: 0.42857130567312407 w2_new:: -0.5000002105686248 b_new: -0.35714288915103065
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.28571398425552996
# Actualizo pesos y bias
# w1_new: 0.5714285088220181 w2_new:: -0.3571430074197307 b_new: -0.5000000922999247
# Epocas: 13 SumaErrores: 1.0204077296889846
#
# --- Epoca: 14 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.2857145908976373
# Actualizo pesos y bias
# w1_new: 0.4285714270015456 w2_new:: -0.5000000892402032 b_new: -0.6428571741203972
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2857143421213516
# Actualizo pesos y bias
# w1_new: 0.5714285585772753 w2_new:: -0.6428572208159329 b_new: -0.5000000425446676
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.7142858219378756
# Actualizo pesos y bias
# w1_new: 0.42857139418970014 w2_new:: -0.5000000564283578 b_new: -0.35714287815709245
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.2857142159184348
# Actualizo pesos y bias
# w1_new: 0.5714285510060132 w2_new:: -0.3571428996120447 b_new: -0.5000000349734055
# Epocas: 14 SumaErrores: 1.020408031735073
#
# --- Epoca: 15 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.285714383579437
# Actualizo pesos y bias
# w1_new: 0.4285714277219006 w2_new:: -0.5000000228961573 b_new: -0.6428571582575181
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2857142923605398
# Actualizo pesos y bias
# w1_new: 0.5714285692497927 w2_new:: -0.6428571644240494 b_new: -0.500000016729626
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.714285750403468
# Actualizo pesos y bias
# w1_new: 0.428571419169099 w2_new:: -0.5000000143433557 b_new: -0.35714286664893236
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.28571427147467565
# Actualizo pesos y bias
# w1_new: 0.5714285648741639 w2_new:: -0.3571428686382908 b_new: -0.5000000123539973
# Epocas: 15 SumaErrores: 1.0204081245838534
#
# --- Epoca: 16 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.28571431611812415
# Actualizo pesos y bias
# w1_new: 0.42857142809778875 w2_new:: -0.500000005414666 b_new: -0.6428571491303725
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.28571428438208235
# Actualizo pesos y bias
# w1_new: 0.5714285712213723 w2_new:: -0.6428571485382496 b_new: -0.500000006006789
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.7142857257664108
# Actualizo pesos y bias
# w1_new: 0.42857142606809007 w2_new:: -0.5000000033849674 b_new: -0.35714286085350677
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.2857142835366294
# Actualizo pesos y bias
# w1_new: 0.5714285693607641 w2_new:: -0.3571428600922933 b_new: -0.500000004146181
# Epocas: 16 SumaErrores: 1.0204081522558193
#
# --- Epoca: 17 ---
# Iteracion: 1
# num1: 1 num2: 1
# Y: -0.2857142948777101
# Actualizo pesos y bias
# w1_new: 0.4285714283363061 w2_new:: -0.5000000011167512 b_new: -0.642857145170639
# Iteracion: 2
# num1: 1 num2: -1
# Y: 0.2857142842824184
# Actualizo pesos y bias
# w1_new: 0.5714285714798224 w2_new:: -0.6428571442602675 b_new: -0.5000000020271227
# Iteracion: 3
# num1: -1 num2: 1
# Y: -1.7142857177672126
# Actualizo pesos y bias
# w1_new: 0.42857142792637987 w2_new:: -0.500000000706825 b_new: -0.35714285847368016
# Iteracion: 4
# num1: -1 num2: -1
# Y: -0.285714285693235
# Actualizo pesos y bias
# w1_new: 0.5714285707877329 w2_new:: -0.35714285784547206 b_new: -0.5000000013350332
# Epocas: 17 SumaErrores: 1.0204081602445862

# %%
# Crear la gráfica de el error cuadrático medio por epoca
epocas = range(1, len(error) + 1)
plt.plot(epocas, error, marker='o', linestyle='-', color='b')  # Línea con puntos marcados
plt.title('Error cuadrático medio (LMS) por Época')  # Título de la gráfica
plt.xlabel('Época')  # Etiqueta del eje X
plt.ylabel('Error cuadrático medio')  # Etiqueta del eje Y
plt.grid(True)  # Agregar una cuadrícula para mejor visualización
plt.xticks(epocas)  # Asegurar que las épocas se muestren correctamente en el eje X
plt.show()  # Mostrar la gráfica

# %%
def validar_entrada(mensaje):
    while True:
        try:
            valor = float(input(mensaje))
            if -1 <= valor <= 1:
                return valor
            else:
                print("Error: El valor debe estar entre -1 y 1. Intente nuevamente.")
        except ValueError:
            print("Error: Ingrese un número válido.")

# Datos de ejemplo (simulando tus datos)
# atributos     ->   [x1, x2]
individuo = np.array([[1, 1], 
                      [1,-1],  
                      [-1,1], 
                      [-1,-1],
                     ])
# 1 : true    -1 : false
clases = np.array([-1, 1, -1, -1])

# Pesos y sesgo (simulando tus valores)
#w1, w2, b = 1.0, 1.0, 0.0  # Ajusta estos valores según tu modelo

# Crear la figura
plt.figure(figsize=(6, 5), dpi=200)
plt.title("Adaline con su recta de clasificacion", fontsize=15)

# Graficar los puntos de entrada
plt.scatter(individuo[clases == -1].T[0], 
            individuo[clases == -1].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="False")
plt.scatter(individuo[clases == 1].T[0],
            individuo[clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")

# Generar y graficar la región de decisión
for x1 in np.arange(-1, 1, 0.05):
    for x2 in np.arange(-1, 1, 0.05):
        # Calcular el valor de y
        y = (w1 * x1) + (w2 * x2) + b
        
        # Función de activación
        if y >= 0:
            color = "blue"  # Clase 1
        else:
            color = "red"   # Clase -1
        
        # Graficar el punto
        plt.scatter(x1, x2, marker="s", s=110,
                    color=color, alpha=0.2, linewidths=0)

# Calcular recta 
r1 = (-(b/w1)) * np.array([1, 0])  # Punto donde x2 = 0
r2 = (-(b/w2)) * np.array([0, 1])  # Punto donde x1 = 0

# Graficar la recta
plt.axline((r1[0], r1[1]), (r2[0], r2[1]), color="green", label="Recta clasificadora")

# Solicitar valores de x1 y x2 al usuario
x1 = validar_entrada("Ingrese x1 con un valor entre -1 y 1: ")
x2 = validar_entrada("Ingrese x2 con un valor entre -1 y 1: ")

# Determinar la clase del punto ingresado
y = (w1 * x1) + (w2 * x2) + b
if y >= 0:
    color = "blue"  # Clase 1
else:
    color = "red"   # Clase -1

# Graficar el punto ingresado
plt.scatter(x1, x2, marker="*", s=200, color=color, label="Punto ingresado")

# Configuraciones adicionales del gráfico
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.show()
# Out:
# Ingrese x1 con un valor entre -1 y 1:  0
# Ingrese x2 con un valor entre -1 y 1:  0
