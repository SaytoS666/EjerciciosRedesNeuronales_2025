# %%
# Este codigo solo muestra los puntos clasifiacados segun su clase
import numpy as np
import matplotlib.pyplot as plt

# atributos     ->   [x1, x2]
individuo = np.array([[1, 0], 
                      [0, 1],  
                      [0, 0], 
                      [1, 1],
                     ])
# 1 : true    -1 : false
clases = np.array([-1, -1, -1, 1])

# Gráfica de dispersión (x1, x2)
plt.figure(figsize=(7, 7))
plt.title("Data SET", fontsize=20)
plt.scatter(individuo [clases == -1].T[0], 
            individuo [clases == -1].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="false")
plt.scatter(individuo [clases == 1].T[0],
            individuo [clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.grid()
plt.show()

# %%
# Este codigo ejecuta las epocas definidas en el while.

w1 = 0.5
w2 = -0.5
# bias   se puede cambiar
b = -1
# parámetro de aprendizaje  se puede cambiar
pa = 0.2
numEpocas=25 # **aqui se cambia el numero de epocas**
# épocas 
epocas = 0
# guarda la suma de los errores por iteracion y vuelve a 0 al incio de cada epoca
sumaErrores=0
# se guarda el error por epoca
error= []
# contaSinError = 0
longitud = len(clases)
# guarda los aciertos de cada epoca
# aciertos = []
while epocas != numEpocas:   
    print("\n--- Epoca:", epocas+1, "---")
    for i in range(individuo.shape[0]):
        print("Iteracion:", i + 1)  # Imprimir el índice de la fila
        print("num1:", individuo[i, 0], "num2:", individuo[i, 1])
        y = (w1 * individuo[i, 0]) + (w2 * individuo[i, 1]) + b
        print("Y:", y)

        # Verificar si la predicción es correcta
        if y == clases[i]:
            print("No actualizo pesos, ni bias")
            #contaSinError += 1
        else:
            print("Actualizo pesos y bias")
            w1 = w1 + pa * (clases[i]-y) * individuo[i, 0]
            w2 = w2 + pa * (clases[i]-y) * individuo[i, 1]
            b = b + pa * (clases[i]-y)
            print("w1_new:", w1, "w2_new::", w2, "b_new:", b)
            # calculo el error en la iteracion correpondiente
            sumaErrores=(((clases[i]-y) ** 2) /2)+sumaErrores
    # Incrementar épocas después de recorrer todos los individuos
    epocas += 1
    print("Epocas:", epocas, "SumaErrores:", sumaErrores)
    error.append(sumaErrores)
    sumaErrores = 0
# Out:
# --- Epoca: 1 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.5
# Actualizo pesos y bias
# w1_new: 0.4 w2_new:: -0.5 b_new: -1.1
# Iteracion: 2
# num1: 0 num2: 1
# Y: -1.6
# Actualizo pesos y bias
# w1_new: 0.4 w2_new:: -0.38 b_new: -0.9800000000000001
# Iteracion: 3
# num1: 0 num2: 0
# Y: -0.9800000000000001
# Actualizo pesos y bias
# w1_new: 0.4 w2_new:: -0.38 b_new: -0.9840000000000001
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.9640000000000001
# Actualizo pesos y bias
# w1_new: 0.7928000000000001 w2_new:: 0.012800000000000034 b_new: -0.5912000000000001
# Epocas: 1 SumaErrores: 2.233848
#
# --- Epoca: 2 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: 0.2016
# Actualizo pesos y bias
# w1_new: 0.5524800000000001 w2_new:: 0.012800000000000034 b_new: -0.83152
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.81872
# Actualizo pesos y bias
# w1_new: 0.5524800000000001 w2_new:: -0.02345599999999997 b_new: -0.867776
# Iteracion: 3
# num1: 0 num2: 0
# Y: -0.867776
# Actualizo pesos y bias
# w1_new: 0.5524800000000001 w2_new:: -0.02345599999999997 b_new: -0.8942208
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.3651967999999999
# Actualizo pesos y bias
# w1_new: 0.8255193600000001 w2_new:: 0.24958336000000003 b_new: -0.62118144
# Epocas: 2 SumaErrores: 1.6789752436531198
#
# --- Epoca: 3 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: 0.20433792000000017
# Actualizo pesos y bias
# w1_new: 0.5846517760000001 w2_new:: 0.24958336000000003 b_new: -0.862049024
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.612465664
# Actualizo pesos y bias
# w1_new: 0.5846517760000001 w2_new:: 0.17207649280000004 b_new: -0.9395558912
# Iteracion: 3
# num1: 0 num2: 0
# Y: -0.9395558912
# Actualizo pesos y bias
# w1_new: 0.5846517760000001 w2_new:: 0.17207649280000004 b_new: -0.9516447129600001
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.19491644415999998
# Actualizo pesos y bias
# w1_new: 0.8236350648320001 w2_new:: 0.4110597816320001 b_new: -0.712661424128
# Epocas: 3 SumaErrores: 1.5160457429707461
#
# --- Epoca: 4 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: 0.11097364070400006
# Actualizo pesos y bias
# w1_new: 0.6014403366912001 w2_new:: 0.4110597816320001 b_new: -0.9348561522688
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.5237963706368
# Actualizo pesos y bias
# w1_new: 0.6014403366912001 w2_new:: 0.3158190557593601 b_new: -1.0300968781414401
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.0300968781414401
# Actualizo pesos y bias
# w1_new: 0.6014403366912001 w2_new:: 0.3158190557593601 b_new: -1.024077502513152
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.1068181100625919
# Actualizo pesos y bias
# w1_new: 0.8228039587037186 w2_new:: 0.5371826777718784 b_new: -0.8027138805006337
# Epocas: 4 SumaErrores: 1.3434922388970865
#
# --- Epoca: 5 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: 0.020090078203084838
# Actualizo pesos y bias
# w1_new: 0.6187859430631016 w2_new:: 0.5371826777718784 b_new: -1.0067318961412508
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.46954921836937236
# Actualizo pesos y bias
# w1_new: 0.6187859430631016 w2_new:: 0.43109252144575294 b_new: -1.1128220524673764
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.1128220524673764
# Actualizo pesos y bias
# w1_new: 0.6187859430631016 w2_new:: 0.43109252144575294 b_new: -1.0902576419739012
# Iteracion: 4
# num1: 1 num2: 1
# Y: -0.0403791774650466
# Actualizo pesos y bias
# w1_new: 0.826861778556111 w2_new:: 0.6391683569387623 b_new: -0.8821818064808918
# Epocas: 5 SumaErrores: 1.208539723903359
#
# --- Epoca: 6 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.05532002792478086
# Actualizo pesos y bias
# w1_new: 0.6379257841410672 w2_new:: 0.6391683569387623 b_new: -1.0711178008959357
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.4319494439571734
# Actualizo pesos y bias
# w1_new: 0.6379257841410672 w2_new:: 0.5255582457301969 b_new: -1.184727912104501
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.184727912104501
# Actualizo pesos y bias
# w1_new: 0.6379257841410672 w2_new:: 0.5255582457301969 b_new: -1.1477823296836007
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.01570170018766337
# Actualizo pesos y bias
# w1_new: 0.8347854441035345 w2_new:: 0.7224179056926643 b_new: -0.9509226697211334
# Epocas: 6 SumaErrores: 1.109034614192273
#
# --- Epoca: 7 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.11613722561759887
# Actualizo pesos y bias
# w1_new: 0.6580128892270543 w2_new:: 0.7224179056926643 b_new: -1.1276952245976135
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.4052773189049492
# Actualizo pesos y bias
# w1_new: 0.6580128892270543 w2_new:: 0.6034733694736542 b_new: -1.2466397608166238
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.2466397608166238
# Actualizo pesos y bias
# w1_new: 0.6580128892270543 w2_new:: 0.6034733694736542 b_new: -1.197311808653299
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.06417445004740951
# Actualizo pesos y bias
# w1_new: 0.8451779992175723 w2_new:: 0.7906384794641723 b_new: -1.010146698662781
# Epocas: 7 SumaErrores: 1.0357545514537954
#
# --- Epoca: 8 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.16496869944520864
# Actualizo pesos y bias
# w1_new: 0.678171739106614 w2_new:: 0.7906384794641723 b_new: -1.1771529587737393
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.38651447930956695
# Actualizo pesos y bias
# w1_new: 0.678171739106614 w2_new:: 0.6679413753260857 b_new: -1.299850062911826
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.299850062911826
# Actualizo pesos y bias
# w1_new: 0.678171739106614 w2_new:: 0.6679413753260857 b_new: -1.2398800503294607
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.10623306410323896
# Actualizo pesos y bias
# w1_new: 0.8569251262859662 w2_new:: 0.8466947625054378 b_new: -1.0611266631501084
# Epocas: 8 SumaErrores: 0.9811855764667745
#
# --- Epoca: 9 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.20420153686414222
# Actualizo pesos y bias
# w1_new: 0.6977654336587946 w2_new:: 0.8466947625054378 b_new: -1.2202863557772798
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.373591593271842
# Actualizo pesos y bias
# w1_new: 0.6977654336587946 w2_new:: 0.7214130811598063 b_new: -1.3455680371229115
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.3455680371229115
# Actualizo pesos y bias
# w1_new: 0.6977654336587946 w2_new:: 0.7214130811598063 b_new: -1.2764544296983291
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.1427240851202718
# Actualizo pesos y bias
# w1_new: 0.8692206166347403 w2_new:: 0.8928682641357519 b_new: -1.1049992467223835
# Epocas: 9 SumaErrores: 0.9400109742314797
#
# --- Epoca: 10 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.23577863008764322
# Actualizo pesos y bias
# w1_new: 0.7163763426522689 w2_new:: 0.8928682641357519 b_new: -1.2578435207048548
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.3649752565691029
# Actualizo pesos y bias
# w1_new: 0.7163763426522689 w2_new:: 0.7658633154495725 b_new: -1.3848484693910343
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.3848484693910343
# Actualizo pesos y bias
# w1_new: 0.7163763426522689 w2_new:: 0.7658633154495725 b_new: -1.3078787755128274
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.17436088258901394
# Actualizo pesos y bias
# w1_new: 0.8815041661344661 w2_new:: 0.9309911389317698 b_new: -1.1427509520306303
# Epocas: 10 SumaErrores: 0.9085395117960049
#
# --- Epoca: 11 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.2612467858961641
# Actualizo pesos y bias
# w1_new: 0.7337535233136989 w2_new:: 0.9309911389317698 b_new: -1.2905015948513974
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.3595104559196276
# Actualizo pesos y bias
# w1_new: 0.7337535233136989 w2_new:: 0.8028932301156952 b_new: -1.418599503667472
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.418599503667472
# Actualizo pesos y bias
# w1_new: 0.7337535233136989 w2_new:: 0.8028932301156952 b_new: -1.3348796029339776
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.2017671504954166
# Actualizo pesos y bias
# w1_new: 0.8934000932146156 w2_new:: 0.9625398000166119 b_new: -1.175233033033061
# Epocas: 11 SumaErrores: 0.884192196961946
#
# --- Epoca: 12 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.28183293981844537
# Actualizo pesos y bias
# w1_new: 0.7497666811783046 w2_new:: 0.9625398000166119 b_new: -1.318866445069372
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.35632664505276
# Actualizo pesos y bias
# w1_new: 0.7497666811783046 w2_new:: 0.8338051290271639 b_new: -1.4476011160588198
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.4476011160588198
# Actualizo pesos y bias
# w1_new: 0.7497666811783046 w2_new:: 0.8338051290271639 b_new: -1.3580808928470558
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.22549091735841276
# Actualizo pesos y bias
# w1_new: 0.904668497706622 w2_new:: 0.9887069455554813 b_new: -1.2031790763187384
# Epocas: 12 SumaErrores: 0.8651451961951333
#
# --- Epoca: 13 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.2985105786121164
# Actualizo pesos y bias
# w1_new: 0.7643706134290453 w2_new:: 0.9887069455554813 b_new: -1.3434769605963153
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.35477001504083394
# Actualizo pesos y bias
# w1_new: 0.7643706134290453 w2_new:: 0.8596609485636482 b_new: -1.4725229575881484
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.4725229575881484
# Actualizo pesos y bias
# w1_new: 0.7643706134290453 w2_new:: 0.8596609485636482 b_new: -1.3780183660705188
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.24601319592217474
# Actualizo pesos y bias
# w1_new: 0.9151679742446104 w2_new:: 1.0104583093792132 b_new: -1.2272210052549537
# Epocas: 13 SumaErrores: 0.8500915939904288
#
# --- Epoca: 14 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.3120530310103433
# Actualizo pesos y bias
# w1_new: 0.777578580446679 w2_new:: 1.0104583093792132 b_new: -1.364810399052885
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.3543520896736718
# Actualizo pesos y bias
# w1_new: 0.777578580446679 w2_new:: 0.8813287273139476 b_new: -1.4939399811181506
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.4939399811181506
# Actualizo pesos y bias
# w1_new: 0.777578580446679 w2_new:: 0.8813287273139476 b_new: -1.3951519848945204
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.26375532286610626
# Actualizo pesos y bias
# w1_new: 0.9248275158734578 w2_new:: 1.0285776627407264 b_new: -1.2479030494677417
# Epocas: 14 SumaErrores: 0.8380825929029002
#
# --- Epoca: 15 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.32307553359428387
# Actualizo pesos y bias
# w1_new: 0.7894426225923146 w2_new:: 1.0285776627407264 b_new: -1.383287942748885
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.3547102800081585
# Actualizo pesos y bias
# w1_new: 0.7894426225923146 w2_new:: 0.899519718742358 b_new: -1.5123458867472532
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.5123458867472532
# Actualizo pesos y bias
# w1_new: 0.7894426225923146 w2_new:: 0.899519718742358 b_new: -1.4098767093978026
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.27908563193686997
# Actualizo pesos y bias
# w1_new: 0.9336254962049406 w2_new:: 1.043702592354984 b_new: -1.2656938357851766
# Epocas: 15 SumaErrores: 0.828420694846252
#
# --- Epoca: 16 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.33206833958023596
# Actualizo pesos y bias
# w1_new: 0.8000391641209879 w2_new:: 1.043702592354984 b_new: -1.3992801678691293
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.35557757551414526
# Actualizo pesos y bias
# w1_new: 0.8000391641209879 w2_new:: 0.9148181074578131 b_new: -1.5281646527663002
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.5281646527663002
# Actualizo pesos y bias
# w1_new: 0.8000391641209879 w2_new:: 0.9148181074578131 b_new: -1.4225317222130403
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.29232554936576083
# Actualizo pesos y bias
# w1_new: 0.9415740542478357 w2_new:: 1.056352997584661 b_new: -1.2809968320861924
# Epocas: 16 SumaErrores: 0.8205869963417745
#
# --- Epoca: 17 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.3394227778383567
# Actualizo pesos y bias
# w1_new: 0.809458609815507 w2_new:: 1.056352997584661 b_new: -1.4131122765185211
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.35675927893386006
# Actualizo pesos y bias
# w1_new: 0.809458609815507 w2_new:: 0.927704853371433 b_new: -1.541760420731749
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.541760420731749
# Actualizo pesos y bias
# w1_new: 0.809458609815507 w2_new:: 0.927704853371433 b_new: -1.4334083365853991
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.303755126601541
# Actualizo pesos y bias
# w1_new: 0.9487075844951988 w2_new:: 1.0669538280511248 b_new: -1.2941593619057072
# Epocas: 17 SumaErrores: 0.8141910844407793
#
# --- Epoca: 18 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.3454517774105085
# Actualizo pesos y bias
# w1_new: 0.8177979399773004 w2_new:: 1.0669538280511248 b_new: -1.4250690064236056
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.35811517837248075
# Actualizo pesos y bias
# w1_new: 0.8177979399773004 w2_new:: 0.938576863725621 b_new: -1.5534459707491095
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.5534459707491095
# Actualizo pesos y bias
# w1_new: 0.8177979399773004 w2_new:: 0.938576863725621 b_new: -1.4427567765992877
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.31361802710363373
# Actualizo pesos y bias
# w1_new: 0.9550743345565738 w2_new:: 1.0758532583048943 b_new: -1.3054803820200145
# Epocas: 18 SumaErrores: 0.8089360775931935
#
# --- Epoca: 19 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.35040604746344073
# Actualizo pesos y bias
# w1_new: 0.825155544049262 w2_new:: 1.0758532583048943 b_new: -1.4353991725273263
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.359545914222432
# Actualizo pesos y bias
# w1_new: 0.825155544049262 w2_new:: 0.9477624411493807 b_new: -1.5634899896828398
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.5634899896828398
# Actualizo pesos y bias
# w1_new: 0.825155544049262 w2_new:: 0.9477624411493807 b_new: -1.450791991746272
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.3221259934523708
# Actualizo pesos y bias
# w1_new: 0.9607303453587878 w2_new:: 1.0833372424589065 b_new: -1.315217190436746
# Epocas: 19 SumaErrores: 0.8045939381934761
#
# --- Epoca: 20 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.35448684507795825
# Actualizo pesos y bias
# w1_new: 0.8316277143743794 w2_new:: 1.0833372424589065 b_new: -1.4443198214211543
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.36098257896224784
# Actualizo pesos y bias
# w1_new: 0.8316277143743794 w2_new:: 0.9555337582513561 b_new: -1.5721233056287047
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.5721233056287047
# Actualizo pesos y bias
# w1_new: 0.8316277143743794 w2_new:: 0.9555337582513561 b_new: -1.4576986445029638
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.32946282812277183
# Actualizo pesos y bias
# w1_new: 0.9657351487498251 w2_new:: 1.0896411926268017 b_new: -1.3235912101275182
# Epocas: 20 SumaErrores: 0.8009878366398877
#
# --- Epoca: 21 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.3578560613776931
# Actualizo pesos y bias
# w1_new: 0.8373063610253637 w2_new:: 1.0896411926268017 b_new: -1.4520199978519797
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.36237880522517796
# Actualizo pesos y bias
# w1_new: 0.8373063610253637 w2_new:: 0.9621169536718372 b_new: -1.5795442368069441
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.5795442368069441
# Actualizo pesos y bias
# w1_new: 0.8373063610253637 w2_new:: 0.9621169536718372 b_new: -1.4636353894455554
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.3357879252516456
# Actualizo pesos y bias
# w1_new: 0.9701487759750346 w2_new:: 1.0949593686215082 b_new: -1.3307929744958844
# Epocas: 21 SumaErrores: 0.7979794142965487
#
# --- Epoca: 22 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.36064419852084983
# Actualizo pesos y bias
# w1_new: 0.8422776156792046 w2_new:: 1.0949593686215082 b_new: -1.4586641347917144
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.3637047661702062
# Actualizo pesos y bias
# w1_new: 0.8422776156792046 w2_new:: 0.9677003218555494 b_new: -1.585923181557673
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.585923181557673
# Actualizo pesos y bias
# w1_new: 0.8422776156792046 w2_new:: 0.9677003218555494 b_new: -1.4687385452461386
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.34123939228861544
# Actualizo pesos y bias
# w1_new: 0.9740297372214815 w2_new:: 1.0994524433978263 b_new: -1.3369864237038616
# Epocas: 22 SumaErrores: 0.7954594892192486
#
# --- Epoca: 23 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.3629566864823801
# Actualizo pesos y bias
# w1_new: 0.8466210745179574 w2_new:: 1.0994524433978263 b_new: -1.4643950864073856
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.36494264300955925
# Actualizo pesos y bias
# w1_new: 0.8466210745179574 w2_new:: 0.9724409719997382 b_new: -1.5914065578054737
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.5914065578054737
# Actualizo pesos y bias
# w1_new: 0.8466210745179574 w2_new:: 0.9724409719997382 b_new: -1.473125246244379
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.34593680027331675
# Actualizo pesos y bias
# w1_new: 0.9774337144632941 w2_new:: 1.1032536119450749 b_new: -1.3423126062990423
# Epocas: 23 SumaErrores: 0.7933412079086095
#
# --- Epoca: 24 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.3648788918357482
# Actualizo pesos y bias
# w1_new: 0.8504094928304438 w2_new:: 1.1032536119450749 b_new: -1.4693368279318926
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.3660832159868177
# Actualizo pesos y bias
# w1_new: 0.8504094928304438 w2_new:: 0.9764702551424385 b_new: -1.596120184734529
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.596120184734529
# Actualizo pesos y bias
# w1_new: 0.8504094928304438 w2_new:: 0.9764702551424385 b_new: -1.4768961477876232
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.349983600185259
# Actualizo pesos y bias
# w1_new: 0.980412772793392 w2_new:: 1.1064735351053867 b_new: -1.346892867824675
# Epocas: 24 SumaErrores: 0.7915549528827246
#
# --- Epoca: 25 ---
# Iteracion: 1
# num1: 1 num2: 0
# Y: -0.366480095031283
# Actualizo pesos y bias
# w1_new: 0.8537087917996486 w2_new:: 1.1064735351053867 b_new: -1.4735968488184183
# Iteracion: 2
# num1: 0 num2: 1
# Y: -0.36712331371303164
# Actualizo pesos y bias
# w1_new: 0.8537087917996486 w2_new:: 0.979898197847993 b_new: -1.600172186075812
# Iteracion: 3
# num1: 0 num2: 0
# Y: -1.600172186075812
# Actualizo pesos y bias
# w1_new: 0.8537087917996486 w2_new:: 0.979898197847993 b_new: -1.4801377488606495
# Iteracion: 4
# num1: 1 num2: 1
# Y: 0.35346924078699216
# Actualizo pesos y bias
# w1_new: 0.9830149436422502 w2_new:: 1.1092043496905946 b_new: -1.350831597018048
# Epocas: 25 SumaErrores: 0.7900445227923567

# %%
# Crear la gráfica de el error cuadrático medio por epoca
epocas = range(1, len(error) + 1)
plt.plot(epocas, error, marker='o', linestyle='-', color='b')  # Línea con puntos marcados
plt.title('Error cuadrático medio (LMS) por Época')  # Título de la gráfica
plt.xlabel('Época')  # Etiqueta del eje X
plt.ylabel('Error cuadrático medio')  # Etiqueta del eje Y
plt.grid(True)  # Agregar una cuadrícula para mejor visualización
plt.xticks(epocas)  # Asegurar que las épocas se muestren correctamente en el eje X
plt.show()  # Mostrar la gráfica

# %%
def validar_entrada(mensaje):
    while True:
        try:
            valor = float(input(mensaje))
            if -1 <= valor <= 1:
                return valor
            else:
                print("Error: El valor debe estar entre -1 y 1. Intente nuevamente.")
        except ValueError:
            print("Error: Ingrese un número válido.")

# Datos de ejemplo (simulando tus datos)
# atributos     ->   [x1, x2]
individuo = np.array([[1, 0], 
                      [0, 1],  
                      [0, 0], 
                      [1, 1],
                     ])
# 1 : true    -1 : false
clases = np.array([-1, -1, -1, 1])

# Pesos y sesgo (simulando tus valores)
#w1, w2, b = 1.0, 1.0, 0.0  # Ajusta estos valores según tu modelo

# Crear la figura
plt.figure(figsize=(6, 5), dpi=200)
plt.title("Adaline con su recta de clasificacion", fontsize=15)

# Graficar los puntos de entrada
plt.scatter(individuo[clases == -1].T[0], 
            individuo[clases == -1].T[1], 
            marker="x", s=120, color="red",
            linewidths=5, label="False")
plt.scatter(individuo[clases == 1].T[0],
            individuo[clases == 1].T[1], 
            marker="o", s=120, color="blue",
            linewidths=5, label="True")

# Generar y graficar la región de decisión
for x1 in np.arange(-1, 1, 0.05):
    for x2 in np.arange(-1, 1, 0.05):
        # Calcular el valor de y
        y = (w1 * x1) + (w2 * x2) + b
        
        # Función de activación
        if y >= 0:
            color = "blue"  # Clase 1
        else:
            color = "red"   # Clase -1
        
        # Graficar el punto
        plt.scatter(x1, x2, marker="s", s=110,
                    color=color, alpha=0.2, linewidths=0)

# Calcular recta 
r1 = (-(b/w1)) * np.array([1, 0])  # Punto donde x2 = 0
r2 = (-(b/w2)) * np.array([0, 1])  # Punto donde x1 = 0

# Graficar la recta
plt.axline((r1[0], r1[1]), (r2[0], r2[1]), color="green", label="Recta clasificadora")

# Solicitar valores de x1 y x2 al usuario
x1 = validar_entrada("Ingrese x1 con un valor entre -1 y 1: ")
x2 = validar_entrada("Ingrese x2 con un valor entre -1 y 1: ")

# Determinar la clase del punto ingresado
y = (w1 * x1) + (w2 * x2) + b
if y >= 0:
    color = "blue"  # Clase 1
else:
    color = "red"   # Clase -1

# Graficar el punto ingresado
plt.scatter(x1, x2, marker="*", s=200, color=color, label="Punto ingresado")

# Configuraciones adicionales del gráfico
plt.xlabel("x1", fontsize=15)
plt.ylabel("x2", fontsize=15)
plt.legend(bbox_to_anchor=(1.3, 0.15))
plt.box(False)
plt.xlim((-1.5, 1.3))
plt.ylim((-1.5, 1.3))
plt.show()
# Out:
# Ingrese x1 con un valor entre -1 y 1:  0.9
# Ingrese x2 con un valor entre -1 y 1:  0.6
